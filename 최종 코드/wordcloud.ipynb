# %% [markdown]
# # 84/ 85 해설서 워드 클라우드

# %%
pip install wordcloud
# Out:
# Collecting wordcloudNote: you may need to restart the kernel to use updated packages.
#
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/f5/b0/247159f61c5d5d6647171bef84430b7efad4db504f0229674024f3a4f7f2/wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (10.0.1)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp311-cp311-win_amd64.whl (300 kB)
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    --------------- ------------------------ 112.6/300.2 kB 1.6 MB/s eta 0:00:01
#    -------------------------------- ------- 245.8/300.2 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 300.2/300.2 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3
# DEPRECATION: mecab-python 0.996-ko-0.9.2-msvc has a non-standard version number. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of mecab-python or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
#   WARNING: The script wordcloud_cli.exe is installed in 'C:\Users\user\anaconda3\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %% [markdown]
# # 84류 해설서

# %%
from wordcloud import WordCloud

# %%
import pandas as pd

text = open('./생성데이터/Chapter 84.txt', encoding='utf-8').read()
text
# Out:
# 'Chapter 84\n\nNuclear reactors, boilers, machinery and\n\nmechanical appliances; parts thereof\n\nNotes.\n\n1.- This Chapter does not cover :\n\n(a) Millstones, grindstones or other articles of Chapter 68;\n\n(b) Machinery or appliances (for example, pumps) of ceramic material and ceramic parts of machinery or appliances of any material (Chapter 69);\n\n(c) Laboratory glassware (heading 70.17); machinery, appliances or other articles for technical uses or parts thereof, of glass (heading 70.19 or 70.20);\n\n(d) Articles of heading 73.21 or 73.22 or similar articles of other base metals (Chapters 74 to 76 or 78 to 81);\n\n(e) Vacuum cleaners of heading 85.08;\n\n(f) Electro-mechanical domestic appliances of heading 85.09; digital cameras of heading 85.25;\n\n(g) Radiators for the articles of Section XVII; or\n\n(h) Hand-operated mechanical floor sweepers, not motorised (heading 96.03).\n\n2.- Subject to the operation of Note 3 to Section XVI and subject to Note 11 to this Chapter, a machine or appliance which answers to a description in one or more of the headings 84.01 to 84.24, or heading 84.86 and at the same time to a description in one or more of the headings 84.25 to 84.80 is to be classified under the appropriate heading of the former group or under heading 84.86, as the case may be, and not the latter group.\n\n(A) Heading 84.19 does not, however, cover :\n\n(ⅰ) Germination plant, incubators or brooders (heading 84.36);\n\n(ⅱ) Grain dampening machines (heading 84.37);\n\n(ⅲ) Diffusing apparatus for sugar juice extraction (heading 84.38);\n\n(ⅳ) Machinery for the heat-treatment of textile yarns, fabrics or made up textile articles (heading 84.51); or\n\n(ⅴ) Machinery, plant or laboratory equipment, designed for a mechanical operation, in which a change of temperature, even if necessary, is subsidiary.\n\n(B) Heading 84.22 does not cover :\n\n(ⅰ) Sewing machines for closing bags or similar containers (heading 84.52); or\n\n(ⅱ) Office machinery of heading 84.72.\n\n(C) Heading 84.24 does not cover :\n\n(ⅰ) Ink-jet printing machines (heading 84.43); or\n\n(ⅱ) Water-jet cutting machines (heading 84.56).\n\n3.- A machine-tool for working any material which answers to a description in heading 84.56 and at the same time to a description in heading 84.57, 84.58, 84.59, 84.60, 84.61, 84.64 or 84.65 is to be classified in heading 84.56.\n\n4.- Heading 84.57 applies only to machine-tools for working metal, other than lathes (including turning centres), which can carry out different types of machining operations either :\n\n(a) by automatic tool change from a magazine or the like in conformity with a machining programme (machining centres),\n\n(b) by the automatic use, simultaneously or sequentially, of different unit heads working on a fixed position workpiece (unit construction machines, single station), or\n\n(c) by the automatic transfer of the workpiece to different unit heads (multi-station transfer machines).\n\n5.- For the purposes of heading 84.62, a “slitting line” for flat products is a processing line composed of an uncoiler, a coil flattener, a slitter and a recoiler. A “cut-to-length line” for flat products is a processing line composed of an uncoiler, a coil flattener, and a shear.\n\n6.- (A) For the purposes of heading 84.71, the expression “automatic data processing machines” means machines capable of :\n\n(i) Storing the processing program or programs and at least the data immediately necessary for the execution of the program;\n\n(ii) Being freely programmed in accordance with the requirements of the user;\n\n(iii) Performing arithmetical computations specified by the user; and\n\n(iv) Executing, without human intervention, a processing program which requires them to modify their execution, by logical decision during the processing run.\n\n(B) Automatic data processing machines may be in the form of systems consisting of a variable number of separate units.\n\n(C) Subject to paragraphs (D) and (E) below, a unit i ...

# %%
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
from nltk.stem import WordNetLemmatizer
import nltk
import string

lemmar = WordNetLemmatizer()
stopwords = nltk.corpus.stopwords.words('english')
string = string.punctuation
for stri in string:
    stopwords.append(stri)

stopwords.append('heading')
stopwords.append('chapter')
words = word_tokenize(text.lower())
print(words)
# Out:
# ['chapter', '84', 'nuclear', 'reactors', ',', 'boilers', ',', 'machinery', 'and', 'mechanical', 'appliances', ';', 'parts', 'thereof', 'notes', '.', '1.-', 'this', 'chapter', 'does', 'not', 'cover', ':', '(', 'a', ')', 'millstones', ',', 'grindstones', 'or', 'other', 'articles', 'of', 'chapter', '68', ';', '(', 'b', ')', 'machinery', 'or', 'appliances', '(', 'for', 'example', ',', 'pumps', ')', 'of', 'ceramic', 'material', 'and', 'ceramic', 'parts', 'of', 'machinery', 'or', 'appliances', 'of', 'any', 'material', '(', 'chapter', '69', ')', ';', '(', 'c', ')', 'laboratory', 'glassware', '(', 'heading', '70.17', ')', ';', 'machinery', ',', 'appliances', 'or', 'other', 'articles', 'for', 'technical', 'uses', 'or', 'parts', 'thereof', ',', 'of', 'glass', '(', 'heading', '70.19', 'or', '70.20', ')', ';', '(', 'd', ')', 'articles', 'of', 'heading', '73.21', 'or', '73.22', 'or', 'similar', 'articles', 'of', 'other', 'base', 'metals', '(', 'chapters', '74', 'to', '76', 'or', '78', 'to', '81', ')', ';', '(', 'e', ')', 'vacuum', 'cleaners', 'of', 'heading', '85.08', ';', '(', 'f', ')', 'electro-mechanical', 'domestic', 'appliances', 'of', 'heading', '85.09', ';', 'digital', 'cameras', 'of', 'heading', '85.25', ';', '(', 'g', ')', 'radiators', 'for', 'the', 'articles', 'of', 'section', 'xvii', ';', 'or', '(', 'h', ')', 'hand-operated', 'mechanical', 'floor', 'sweepers', ',', 'not', 'motorised', '(', 'heading', '96.03', ')', '.', '2.-', 'subject', 'to', 'the', 'operation', 'of', 'note', '3', 'to', 'section', 'xvi', 'and', 'subject', 'to', 'note', '11', 'to', 'this', 'chapter', ',', 'a', 'machine', 'or', 'appliance', 'which', 'answers', 'to', 'a', 'description', 'in', 'one', 'or', 'more', 'of', 'the', 'headings', '84.01', 'to', '84.24', ',', 'or', 'heading', '84.86', 'and', 'at', 'the', 'same', 'time', 'to', 'a', 'description', 'in', 'one', 'or', 'more', 'of', 'the', 'headings', '84.25', 'to', '84.80', 'is', 'to', 'be', 'classified', 'under', 'the', 'appropriate', 'heading', 'of', 'the', 'former', 'group', 'or', 'under', 'heading', '84.86', ',', 'as', 'the', 'case', 'may', 'be', ',', 'and', 'not', 'the', 'latter', 'group', '.', '(', 'a', ')', 'heading', '84.19', 'does', 'not', ',', 'however', ',', 'cover', ':', '(', 'ⅰ', ')', 'germination', 'plant', ',', 'incubators', 'or', 'brooders', '(', 'heading', '84.36', ')', ';', '(', 'ⅱ', ')', 'grain', 'dampening', 'machines', '(', 'heading', '84.37', ')', ';', '(', 'ⅲ', ')', 'diffusing', 'apparatus', 'for', 'sugar', 'juice', 'extraction', '(', 'heading', '84.38', ')', ';', '(', 'ⅳ', ')', 'machinery', 'for', 'the', 'heat-treatment', 'of', 'textile', 'yarns', ',', 'fabrics', 'or', 'made', 'up', 'textile', 'articles', '(', 'heading', '84.51', ')', ';', 'or', '(', 'ⅴ', ')', 'machinery', ',', 'plant', 'or', 'laboratory', 'equipment', ',', 'designed', 'for', 'a', 'mechanical', 'operation', ',', 'in', 'which', 'a', 'change', 'of', 'temperature', ',', 'even', 'if', 'necessary', ',', 'is', 'subsidiary', '.', '(', 'b', ')', 'heading', '84.22', 'does', 'not', 'cover', ':', '(', 'ⅰ', ')', 'sewing', 'machines', 'for', 'closing', 'bags', 'or', 'similar', 'containers', '(', 'heading', '84.52', ')', ';', 'or', '(', 'ⅱ', ')', 'office', 'machinery', 'of', 'heading', '84.72', '.', '(', 'c', ')', 'heading', '84.24', 'does', 'not', 'cover', ':', '(', 'ⅰ', ')', 'ink-jet', 'printing', 'machines', '(', 'heading', '84.43', ')', ';', 'or', '(', 'ⅱ', ')', 'water-jet', 'cutting', 'machines', '(', 'heading', '84.56', ')', '.', '3.-', 'a', 'machine-tool', 'for', 'working', 'any', 'material', 'which', 'answers', 'to', 'a', 'description', 'in', 'heading', '84.56', 'and', 'at', 'the', 'same', 'time', 'to', 'a', 'description', 'in', 'heading', '84.57', ',', '84.58', ',', '84.59', ',', '84.60', ',', '84.61', ',', '84.64', 'or', '84.65', 'is', 'to', 'be', 'classified', 'in', 'heading', '84.56', '.', '4.-', 'heading', '84.57', 'applies', 'only', 'to', 'machine-tools', 'for', 'working', 'metal', ',', 'other', 'than', 'lathes', '(', 'in ...

# %%
word_list = []

for word in words:
    if word not in stopwords:
        word_list.append(word)

word_list
# Out:
# ['84',
#  'nuclear',
#  'reactors',
#  'boilers',
#  'machinery',
#  'mechanical',
#  'appliances',
#  'parts',
#  'thereof',
#  'notes',
#  '1.-',
#  'cover',
#  'millstones',
#  'grindstones',
#  'articles',
#  '68',
#  'b',
#  'machinery',
#  'appliances',
#  'example',
#  'pumps',
#  'ceramic',
#  'material',
#  'ceramic',
#  'parts',
#  'machinery',
#  'appliances',
#  'material',
#  '69',
#  'c',
#  'laboratory',
#  'glassware',
#  '70.17',
#  'machinery',
#  'appliances',
#  'articles',
#  'technical',
#  'uses',
#  'parts',
#  'thereof',
#  'glass',
#  '70.19',
#  '70.20',
#  'articles',
#  '73.21',
#  '73.22',
#  'similar',
#  'articles',
#  'base',
#  'metals',
#  'chapters',
#  '74',
#  '76',
#  '78',
#  '81',
#  'e',
#  'vacuum',
#  'cleaners',
#  '85.08',
#  'f',
#  'electro-mechanical',
#  'domestic',
#  'appliances',
#  '85.09',
#  'digital',
#  'cameras',
#  '85.25',
#  'g',
#  'radiators',
#  'articles',
#  'section',
#  'xvii',
#  'h',
#  'hand-operated',
#  'mechanical',
#  'floor',
#  'sweepers',
#  'motorised',
#  '96.03',
#  '2.-',
#  'subject',
#  'operation',
#  'note',
#  '3',
#  'section',
#  'xvi',
#  'subject',
#  'note',
#  '11',
#  'machine',
#  'appliance',
#  'answers',
#  'description',
#  'one',
#  'headings',
#  '84.01',
#  '84.24',
#  '84.86',
#  'time',
#  'description',
#  'one',
#  'headings',
#  '84.25',
#  '84.80',
#  'classified',
#  'appropriate',
#  'former',
#  'group',
#  '84.86',
#  'case',
#  'may',
#  'latter',
#  'group',
#  '84.19',
#  'however',
#  'cover',
#  'ⅰ',
#  'germination',
#  'plant',
#  'incubators',
#  'brooders',
#  '84.36',
#  'ⅱ',
#  'grain',
#  'dampening',
#  'machines',
#  '84.37',
#  'ⅲ',
#  'diffusing',
#  'apparatus',
#  'sugar',
#  'juice',
#  'extraction',
#  '84.38',
#  'ⅳ',
#  'machinery',
#  'heat-treatment',
#  'textile',
#  'yarns',
#  'fabrics',
#  'made',
#  'textile',
#  'articles',
#  '84.51',
#  'ⅴ',
#  'machinery',
#  'plant',
#  'laboratory',
#  'equipment',
#  'designed',
#  'mechanical',
#  'operation',
#  'change',
#  'temperature',
#  'even',
#  'necessary',
#  'subsidiary',
#  'b',
#  '84.22',
#  'cover',
#  'ⅰ',
#  'sewing',
#  'machines',
#  'closing',
#  'bags',
#  'similar',
#  'containers',
#  '84.52',
#  'ⅱ',
#  'office',
#  'machinery',
#  '84.72',
#  'c',
#  '84.24',
#  'cover',
#  'ⅰ',
#  'ink-jet',
#  'printing',
#  'machines',
#  '84.43',
#  'ⅱ',
#  'water-jet',
#  'cutting',
#  'machines',
#  '84.56',
#  '3.-',
#  'machine-tool',
#  'working',
#  'material',
#  'answers',
#  'description',
#  '84.56',
#  'time',
#  'description',
#  '84.57',
#  '84.58',
#  '84.59',
#  '84.60',
#  '84.61',
#  '84.64',
#  '84.65',
#  'classified',
#  '84.56',
#  '4.-',
#  '84.57',
#  'applies',
#  'machine-tools',
#  'working',
#  'metal',
#  'lathes',
#  'including',
#  'turning',
#  'centres',
#  'carry',
#  'different',
#  'types',
#  'machining',
#  'operations',
#  'either',
#  'automatic',
#  'tool',
#  'change',
#  'magazine',
#  'like',
#  'conformity',
#  'machining',
#  'programme',
#  'machining',
#  'centres',
#  'b',
#  'automatic',
#  'use',
#  'simultaneously',
#  'sequentially',
#  'different',
#  'unit',
#  'heads',
#  'working',
#  'fixed',
#  'position',
#  'workpiece',
#  'unit',
#  'construction',
#  'machines',
#  'single',
#  'station',
#  'c',
#  'automatic',
#  'transfer',
#  'workpiece',
#  'different',
#  'unit',
#  'heads',
#  'multi-station',
#  'transfer',
#  'machines',
#  '5.-',
#  'purposes',
#  '84.62',
#  '“',
#  'slitting',
#  'line',
#  '”',
#  'flat',
#  'products',
#  'processing',
#  'line',
#  'composed',
#  'uncoiler',
#  'coil',
#  'flattener',
#  'slitter',
#  'recoiler',
#  '“',
#  'cut-to-length',
#  'line',
#  '”',
#  'flat',
#  'products',
#  'processing',
#  'line',
#  'composed',
#  'uncoiler',
#  'coil',
#  'flattener',
#  'shear',
#  '6.-',
#  'purposes',
#  '84.71',
#  'expression',
#  '“',
#  'automatic',
#  'data',
#  'processing',
#  'machines',
#  '”',
#  'means',
#  'machines',
#  'capable',
#  'storing',
#  'processing',
#  'program',
#  'programs',
#  'least',
#  'data',
#  'immediately',
#  'necessary',
#  'execution',
#  'program',
#  'ii',
#  'freely',
#  'programmed',
#  'accordance',
#  'requirements',
#  'user',
#  'iii',
#  'performing',
#  'arithmetical',
#  'computations',
#  'specified',
#  'user',
#  'iv',
#  'executing',
#  'without',
#  'human',
#  'intervention',
#  'processing',
#  'program',
#  'requires',
#  'modify',
#  'execution',
#  'logical',
#  'decision',
#  'processing',
#  'run',
#  'b',
#  'automatic',
#  'data',
#  'processing',
#  'machines',
#  'may',
#  'form',
#  'systems',
#  'consisting',
#  'variable',
#  'number',
#  'separate',
#  'units',
#  'c',
#  'subject',
#  'paragraphs',
#  'e',
#  'unit',
#  'regarded',
#  'part',
#  'automatic',
#  'data',
#  'processing',
#  'system',
#  'meets',
#  'following',
#  'conditions',
#  'kind',
#  'solely',
#  'principally',
#  'used',
#  'automatic',
#  'data',
#  'processing',
#  'system',
#  'ii',
#  'connectable',
#  'central',
#  'processing',
#  'unit',
#  'either',
#  'directly',
#  'one',
#  'units',
#  'iii',
#  'able',
#  'accept',
#  'deliver',
#  'data',
#  'form',
#  'codes',
#  'signals',
#  'used',
#  'system',
#  'separately',
#  'presented',
#  'units',
#  'automatic',
#  'data',
#  'processing',
#  'machine',
#  'classified',
#  '84.71.',
#  'however',
#  'keyboards',
#  'x-y',
#  'co-ordinate',
#  'input',
#  'devices',
#  'disk',
#  'storage',
#  'units',
#  'satisfy',
#  'conditions',
#  'paragraphs',
#  'c',
#  'ii',
#  'c',
#  'iii',
#  'cases',
#  'classified',
#  'units',
#  '84.71',
#  '84.71',
#  'cover',
#  'following',
#  'presented',
#  'separately',
#  'even',
#  'meet',
#  'conditions',
#  'set',
#  'forth',
#  'note',
#  '6',
#  'c',
#  'printers',
#  'copying',
#  'machines',
#  'facsimile',
#  'machines',
#  'whether',
#  'combined',
#  'ii',
#  'apparatus',
#  'transmission',
#  'reception',
#  'voice',
#  'images',
#  'data',
#  'including',
#  'apparatus',
#  'communication',
#  'wired',
#  'wireless',
#  'network',
#  'local',
#  'wide',
#  'area',
#  'network',
#  'iii',
#  'loudspeakers',
#  'microphones',
#  'iv',
#  'television',
#  'cameras',
#  'digital',
#  'cameras',
#  'video',
#  'camera',
#  'recorders',
#  'v',
#  'monitors',
#  'projectors',
#  'incorporating',
#  'television',
#  'reception',
#  'apparatus',
#  'e',
#  'machines',
#  'incorporating',
#  'working',
#  'conjunction',
#  'automatic',
#  'data',
#  'processing',
#  'machine',
#  'performing',
#  'specific',
#  'function',
#  'data',
#  'processing',
#  'classified',
#  'headings',
#  'appropriate',
#  'respective',
#  'functions',
#  'failing',
#  'residual',
#  'headings',
#  '7.-',
#  '84.82',
#  'applies',
#  'inter',
#  'alia',
#  'polished',
#  'steel',
#  'balls',
#  'maximum',
#  'minimum',
#  'diameters',
#  'differ',
#  'nominal',
#  'diameter',
#  '1',
#  '0.05',
#  'mm',
#  'whichever',
#  'less',
#  'steel',
#  'balls',
#  'classified',
#  '73.26',
#  '8.-',
#  'machine',
#  'used',
#  'one',
#  'purpose',
#  'purposes',
#  'classification',
#  'treated',
#  'principal',
#  'purpose',
#  'sole',
#  'purpose',
#  'subject',
#  'note',
#  '2',
#  'note',
#  '3',
#  'section',
#  'xvi',
#  'machine',
#  'principal',
#  'purpose',
#  'described',
#  'one',
#  'purpose',
#  'principal',
#  'purpose',
#  'unless',
#  'context',
#  'otherwise',
#  'requires',
#  'classified',
#  '84.79.',
#  '84.79',
#  'also',
#  'covers',
#  'machines',
#  'making',
#  'rope',
#  'cable',
#  'example',
#  'stranding',
#  'twisting',
#  'cabling',
#  'machines',
#  'metal',
#  'wire',
#  'textile',
#  'yarn',
#  'material',
#  'combination',
#  'materials',
#  '9.-',
#  'purposes',
#  '84.70',
#  'term',
#  '“',
#  'pocket-size',
#  '”',
#  'applies',
#  'machines',
#  'dimensions',
#  'exceed',
#  '170',
#  'mm',
#  'x',
#  '100',
#  'mm',
#  'x',
#  '45',
#  'mm',
#  '10',
#  'purposes',
#  '84.85',
#  'expression',
#  '“',
#  'additive',
#  'manufacturing',
#  '”',
#  'also',
#  'referred',
#  '3d',
#  'printing',
#  'means',
#  'formation',
#  'physical',
#  'objects',
#  'based',
#  'digital',
#  'model',
#  'successive',
#  'addition',
#  'layering',
#  'consolidation',
#  'solidification',
#  'material',
#  'example',
#  'metal',
#  'plastics',
#  'ceramics',
#  'subject',
#  'note',
#  '1',
#  'section',
#  'xvi',
#  'note',
#  '1',
#  '84',
#  'machines',
#  'answering',
#  'description',
#  '84.85',
#  'classified',
#  'nomenclature',
#  '11',
#  'notes',
#  '12',
#  '12',
#  'b',
#  '85',
#  'also',
#  'apply',
#  'respect',
#  'expressions',
#  '“',
#  'semiconductor',
#  'devices',
#  '”',
#  '“',
#  'electronic',
#  'integrated',
#  'circuits',
#  '”',
#  'respectively',
#  'used',
#  'note',
#  '84.86.',
#  'however',
#  'purposes',
#  'note',
#  '84.86',
#  'expression',
#  '“',
#  'semiconductor',
#  'devices',
#  '”',
#  'also',
#  'covers',
#  'photosensitive',
#  'semiconductor',
#  'devices',
#  'light-emitting',
#  'diodes',
#  'led',
#  'b',
#  'purposes',
#  'note',
#  '84.86',
#  'expression',
#  '“',
#  'manufacture',
#  'flat',
#  'panel',
#  'displays',
#  '”',
#  'covers',
#  'fabrication',
#  'substrates',
#  'flat',
#  'panel',
#  'cover',
#  'manufacture',
#  'glass',
#  'assembly',
#  'printed',
#  'circuit',
#  'boards',
#  'electronic',
#  'components',
#  'onto',
#  'flat',
#  'panel',
#  'expression',
#  '“',
#  'flat',
#  'panel',
#  'display',
#  '”',
#  'cover',
#  'cathode-ray',
#  'tube',
#  'technology',
#  'c',
#  '84.86',
#  'also',
#  'includes',
#  'machines',
#  'apparatus',
#  'solely',
#  'principally',
#  'kind',
#  'used',
#  'manufacture',
#  'repair',
#  'masks',
#  'reticles',
#  'ii',
#  'assembling',
#  'semiconductor',
#  'devices',
#  'electronic',
#  'integrated',
#  'circuits',
#  'iii',
#  'lifting',
#  'handling',
#  'loading',
#  'unloading',
#  'boules',
#  'wafers',
#  'semiconductor',
#  'devices',
#  'electronic',
#  'integrated',
#  'circuits',
#  'flat',
#  'panel',
#  'displays',
#  'subject',
#  'note',
#  '1',
#  'section',
#  'xvi',
#  'note',
#  '1',
#  '84',
#  'machines',
#  'apparatus',
#  'answering',
#  'description',
#  '84.86',
#  'classified',
#  'nomenclature',
#  '°',
#  '°',
#  '°',
#  'subheading',
#  'notes',
#  '1.-',
#  'purposes',
#  'subheading',
#  '8465.20',
#  'term',
#  '“',
#  'machining',
#  'centres',
#  '”',
#  'applies',
#  'machine-tools',
#  'working',
#  'wood',
#  'cork',
#  'bone',
#  'hard',
#  'rubber',
#  'hard',
#  'plastics',
#  'similar',
#  'hard',
#  'materials',
#  'carry',
#  'different',
#  'types',
#  'machining',
#  'operations',
#  'automatic',
#  'tool',
#  'change',
#  'magazine',
#  'like',
#  'conformity',
#  'machining',
#  'programme',
#  '2.-',
#  'purposes',
#  'subheading',
#  '8471.49',
#  'term',
#  '“',
#  'systems',
#  '”',
#  'means',
#  'automatic',
#  'data',
#  'processing',
#  'machines',
#  'whose',
#  'units',
#  'satisfy',
#  'conditions',
#  'laid',
#  'note',
#  '6',
#  'c',
#  '84',
#  'comprise',
#  'least',
#  'central',
#  'processing',
#  'unit',
#  'one',
#  'input',
#  'unit',
#  'example',
#  'keyboard',
#  'scanner',
#  'one',
#  'output',
#  'unit',
#  'example',
#  'visual',
#  'display',
#  'unit',
#  'printer',
#  '3.-',
#  'purposes',
#  'subheading',
#  '8481.20',
#  'expression',
#  '“',
#  'valves',
#  'oleohydraulic',
#  'pneumatic',
#  'transmissions',
#  '”',
#  'means',
#  'valves',
#  'used',
#  'specifically',
#  'transmission',
#  '“',
#  'fluid',
#  'power',
#  '”',
#  'hydraulic',
#  'pneumatic',
#  'system',
#  'energy',
#  'source',
#  'supplied',
#  'form',
#  'pressurised',
#  'fluids',
#  'liquid',
#  'gas',
#  'valves',
#  'may',
#  'type',
#  'example',
#  'pressure-reducing',
#  'type',
#  'check',
#  'type',
#  'subheading',
#  '8481.20',
#  'takes',
#  'precedence',
#  'subheadings',
#  '84.81',
#  '4.-',
#  'subheading',
#  '8482.40',
#  'applies',
#  'bearings',
#  'cylindrical',
#  'rollers',
#  'uniform',
#  'diameter',
#  'exceeding',
#  '5',
#  'mm',
#  'length',
#  'least',
#  'three',
#  'times',
#  'diameter',
#  'ends',
#  'rollers',
#  'may',
#  'rounded',
#  'general',
#  'general',
#  'content',
#  'subject',
#  'provisions',
#  'general',
#  'explanatory',
#  'note',
#  'section',
#  'xvi',
#  'covers',
#  'machinery',
#  'mechanical',
#  'appliances',
#  'parts',
#  'thereof',
#  'specifically',
#  'covered',
#  '85',
#  'articles',
#  'textile',
#  'material',
#  'technical',
#  'uses',
#  '59.11',
#  'b',
#  'articles',
#  'stone',
#  'etc.',
#  '68',
#  'c',
#  'ceramic',
#  'articles',
#  '69',
#  'laboratory',
#  'glassware',
#  '70.17',
#  'machinery',
#  'appliances',
#  'parts',
#  'thereof',
#  'glass',
#  '70.19',
#  '70.20',
#  'e',
#  'stoves',
#  'central',
#  'heating',
#  'radiators',
#  'goods',
#  '73.21',
#  '73.22',
#  'similar',
#  'articles',
#  'base',
#  'metals',
#  'f',
#  'electro-mechanical',
#  'domestic',
#  'appliances',
#  '85.09',
#  'digital',
#  'cameras',
#  '85.25',
#  'g',
#  'radiators',
#  'articles',
#  'section',
#  'xvii',
#  'section',
#  'xvii',
#  'h',
#  'hand-operated',
#  'mechanical',
#  'floor',
#  'sweepers',
#  'motorised',
#  '96.03',
#  'general',
#  '84',
#  'covers',
#  'machinery',
#  'mechanical',
#  'apparatus',
#  '85',
#  'electrical',
#  'goods',
#  'however',
#  'certain',
#  'machines',
#  'specified',
#  'headings',
#  ...]

# %%
token_list = [lemmar.lemmatize(w) for w in word_list]
token_list
# Out:
# ['84',
#  'nuclear',
#  'reactor',
#  'boiler',
#  'machinery',
#  'mechanical',
#  'appliance',
#  'part',
#  'thereof',
#  'note',
#  '1.-',
#  'cover',
#  'millstone',
#  'grindstone',
#  'article',
#  '68',
#  'b',
#  'machinery',
#  'appliance',
#  'example',
#  'pump',
#  'ceramic',
#  'material',
#  'ceramic',
#  'part',
#  'machinery',
#  'appliance',
#  'material',
#  '69',
#  'c',
#  'laboratory',
#  'glassware',
#  '70.17',
#  'machinery',
#  'appliance',
#  'article',
#  'technical',
#  'us',
#  'part',
#  'thereof',
#  'glass',
#  '70.19',
#  '70.20',
#  'article',
#  '73.21',
#  '73.22',
#  'similar',
#  'article',
#  'base',
#  'metal',
#  'chapter',
#  '74',
#  '76',
#  '78',
#  '81',
#  'e',
#  'vacuum',
#  'cleaner',
#  '85.08',
#  'f',
#  'electro-mechanical',
#  'domestic',
#  'appliance',
#  '85.09',
#  'digital',
#  'camera',
#  '85.25',
#  'g',
#  'radiator',
#  'article',
#  'section',
#  'xvii',
#  'h',
#  'hand-operated',
#  'mechanical',
#  'floor',
#  'sweeper',
#  'motorised',
#  '96.03',
#  '2.-',
#  'subject',
#  'operation',
#  'note',
#  '3',
#  'section',
#  'xvi',
#  'subject',
#  'note',
#  '11',
#  'machine',
#  'appliance',
#  'answer',
#  'description',
#  'one',
#  'heading',
#  '84.01',
#  '84.24',
#  '84.86',
#  'time',
#  'description',
#  'one',
#  'heading',
#  '84.25',
#  '84.80',
#  'classified',
#  'appropriate',
#  'former',
#  'group',
#  '84.86',
#  'case',
#  'may',
#  'latter',
#  'group',
#  '84.19',
#  'however',
#  'cover',
#  'ⅰ',
#  'germination',
#  'plant',
#  'incubator',
#  'brooder',
#  '84.36',
#  'ⅱ',
#  'grain',
#  'dampening',
#  'machine',
#  '84.37',
#  'ⅲ',
#  'diffusing',
#  'apparatus',
#  'sugar',
#  'juice',
#  'extraction',
#  '84.38',
#  'ⅳ',
#  'machinery',
#  'heat-treatment',
#  'textile',
#  'yarn',
#  'fabric',
#  'made',
#  'textile',
#  'article',
#  '84.51',
#  'ⅴ',
#  'machinery',
#  'plant',
#  'laboratory',
#  'equipment',
#  'designed',
#  'mechanical',
#  'operation',
#  'change',
#  'temperature',
#  'even',
#  'necessary',
#  'subsidiary',
#  'b',
#  '84.22',
#  'cover',
#  'ⅰ',
#  'sewing',
#  'machine',
#  'closing',
#  'bag',
#  'similar',
#  'container',
#  '84.52',
#  'ⅱ',
#  'office',
#  'machinery',
#  '84.72',
#  'c',
#  '84.24',
#  'cover',
#  'ⅰ',
#  'ink-jet',
#  'printing',
#  'machine',
#  '84.43',
#  'ⅱ',
#  'water-jet',
#  'cutting',
#  'machine',
#  '84.56',
#  '3.-',
#  'machine-tool',
#  'working',
#  'material',
#  'answer',
#  'description',
#  '84.56',
#  'time',
#  'description',
#  '84.57',
#  '84.58',
#  '84.59',
#  '84.60',
#  '84.61',
#  '84.64',
#  '84.65',
#  'classified',
#  '84.56',
#  '4.-',
#  '84.57',
#  'applies',
#  'machine-tools',
#  'working',
#  'metal',
#  'lathe',
#  'including',
#  'turning',
#  'centre',
#  'carry',
#  'different',
#  'type',
#  'machining',
#  'operation',
#  'either',
#  'automatic',
#  'tool',
#  'change',
#  'magazine',
#  'like',
#  'conformity',
#  'machining',
#  'programme',
#  'machining',
#  'centre',
#  'b',
#  'automatic',
#  'use',
#  'simultaneously',
#  'sequentially',
#  'different',
#  'unit',
#  'head',
#  'working',
#  'fixed',
#  'position',
#  'workpiece',
#  'unit',
#  'construction',
#  'machine',
#  'single',
#  'station',
#  'c',
#  'automatic',
#  'transfer',
#  'workpiece',
#  'different',
#  'unit',
#  'head',
#  'multi-station',
#  'transfer',
#  'machine',
#  '5.-',
#  'purpose',
#  '84.62',
#  '“',
#  'slitting',
#  'line',
#  '”',
#  'flat',
#  'product',
#  'processing',
#  'line',
#  'composed',
#  'uncoiler',
#  'coil',
#  'flattener',
#  'slitter',
#  'recoiler',
#  '“',
#  'cut-to-length',
#  'line',
#  '”',
#  'flat',
#  'product',
#  'processing',
#  'line',
#  'composed',
#  'uncoiler',
#  'coil',
#  'flattener',
#  'shear',
#  '6.-',
#  'purpose',
#  '84.71',
#  'expression',
#  '“',
#  'automatic',
#  'data',
#  'processing',
#  'machine',
#  '”',
#  'mean',
#  'machine',
#  'capable',
#  'storing',
#  'processing',
#  'program',
#  'program',
#  'least',
#  'data',
#  'immediately',
#  'necessary',
#  'execution',
#  'program',
#  'ii',
#  'freely',
#  'programmed',
#  'accordance',
#  'requirement',
#  'user',
#  'iii',
#  'performing',
#  'arithmetical',
#  'computation',
#  'specified',
#  'user',
#  'iv',
#  'executing',
#  'without',
#  'human',
#  'intervention',
#  'processing',
#  'program',
#  'requires',
#  'modify',
#  'execution',
#  'logical',
#  'decision',
#  'processing',
#  'run',
#  'b',
#  'automatic',
#  'data',
#  'processing',
#  'machine',
#  'may',
#  'form',
#  'system',
#  'consisting',
#  'variable',
#  'number',
#  'separate',
#  'unit',
#  'c',
#  'subject',
#  'paragraph',
#  'e',
#  'unit',
#  'regarded',
#  'part',
#  'automatic',
#  'data',
#  'processing',
#  'system',
#  'meet',
#  'following',
#  'condition',
#  'kind',
#  'solely',
#  'principally',
#  'used',
#  'automatic',
#  'data',
#  'processing',
#  'system',
#  'ii',
#  'connectable',
#  'central',
#  'processing',
#  'unit',
#  'either',
#  'directly',
#  'one',
#  'unit',
#  'iii',
#  'able',
#  'accept',
#  'deliver',
#  'data',
#  'form',
#  'code',
#  'signal',
#  'used',
#  'system',
#  'separately',
#  'presented',
#  'unit',
#  'automatic',
#  'data',
#  'processing',
#  'machine',
#  'classified',
#  '84.71.',
#  'however',
#  'keyboard',
#  'x-y',
#  'co-ordinate',
#  'input',
#  'device',
#  'disk',
#  'storage',
#  'unit',
#  'satisfy',
#  'condition',
#  'paragraph',
#  'c',
#  'ii',
#  'c',
#  'iii',
#  'case',
#  'classified',
#  'unit',
#  '84.71',
#  '84.71',
#  'cover',
#  'following',
#  'presented',
#  'separately',
#  'even',
#  'meet',
#  'condition',
#  'set',
#  'forth',
#  'note',
#  '6',
#  'c',
#  'printer',
#  'copying',
#  'machine',
#  'facsimile',
#  'machine',
#  'whether',
#  'combined',
#  'ii',
#  'apparatus',
#  'transmission',
#  'reception',
#  'voice',
#  'image',
#  'data',
#  'including',
#  'apparatus',
#  'communication',
#  'wired',
#  'wireless',
#  'network',
#  'local',
#  'wide',
#  'area',
#  'network',
#  'iii',
#  'loudspeaker',
#  'microphone',
#  'iv',
#  'television',
#  'camera',
#  'digital',
#  'camera',
#  'video',
#  'camera',
#  'recorder',
#  'v',
#  'monitor',
#  'projector',
#  'incorporating',
#  'television',
#  'reception',
#  'apparatus',
#  'e',
#  'machine',
#  'incorporating',
#  'working',
#  'conjunction',
#  'automatic',
#  'data',
#  'processing',
#  'machine',
#  'performing',
#  'specific',
#  'function',
#  'data',
#  'processing',
#  'classified',
#  'heading',
#  'appropriate',
#  'respective',
#  'function',
#  'failing',
#  'residual',
#  'heading',
#  '7.-',
#  '84.82',
#  'applies',
#  'inter',
#  'alia',
#  'polished',
#  'steel',
#  'ball',
#  'maximum',
#  'minimum',
#  'diameter',
#  'differ',
#  'nominal',
#  'diameter',
#  '1',
#  '0.05',
#  'mm',
#  'whichever',
#  'le',
#  'steel',
#  'ball',
#  'classified',
#  '73.26',
#  '8.-',
#  'machine',
#  'used',
#  'one',
#  'purpose',
#  'purpose',
#  'classification',
#  'treated',
#  'principal',
#  'purpose',
#  'sole',
#  'purpose',
#  'subject',
#  'note',
#  '2',
#  'note',
#  '3',
#  'section',
#  'xvi',
#  'machine',
#  'principal',
#  'purpose',
#  'described',
#  'one',
#  'purpose',
#  'principal',
#  'purpose',
#  'unless',
#  'context',
#  'otherwise',
#  'requires',
#  'classified',
#  '84.79.',
#  '84.79',
#  'also',
#  'cover',
#  'machine',
#  'making',
#  'rope',
#  'cable',
#  'example',
#  'stranding',
#  'twisting',
#  'cabling',
#  'machine',
#  'metal',
#  'wire',
#  'textile',
#  'yarn',
#  'material',
#  'combination',
#  'material',
#  '9.-',
#  'purpose',
#  '84.70',
#  'term',
#  '“',
#  'pocket-size',
#  '”',
#  'applies',
#  'machine',
#  'dimension',
#  'exceed',
#  '170',
#  'mm',
#  'x',
#  '100',
#  'mm',
#  'x',
#  '45',
#  'mm',
#  '10',
#  'purpose',
#  '84.85',
#  'expression',
#  '“',
#  'additive',
#  'manufacturing',
#  '”',
#  'also',
#  'referred',
#  '3d',
#  'printing',
#  'mean',
#  'formation',
#  'physical',
#  'object',
#  'based',
#  'digital',
#  'model',
#  'successive',
#  'addition',
#  'layering',
#  'consolidation',
#  'solidification',
#  'material',
#  'example',
#  'metal',
#  'plastic',
#  'ceramic',
#  'subject',
#  'note',
#  '1',
#  'section',
#  'xvi',
#  'note',
#  '1',
#  '84',
#  'machine',
#  'answering',
#  'description',
#  '84.85',
#  'classified',
#  'nomenclature',
#  '11',
#  'note',
#  '12',
#  '12',
#  'b',
#  '85',
#  'also',
#  'apply',
#  'respect',
#  'expression',
#  '“',
#  'semiconductor',
#  'device',
#  '”',
#  '“',
#  'electronic',
#  'integrated',
#  'circuit',
#  '”',
#  'respectively',
#  'used',
#  'note',
#  '84.86.',
#  'however',
#  'purpose',
#  'note',
#  '84.86',
#  'expression',
#  '“',
#  'semiconductor',
#  'device',
#  '”',
#  'also',
#  'cover',
#  'photosensitive',
#  'semiconductor',
#  'device',
#  'light-emitting',
#  'diode',
#  'led',
#  'b',
#  'purpose',
#  'note',
#  '84.86',
#  'expression',
#  '“',
#  'manufacture',
#  'flat',
#  'panel',
#  'display',
#  '”',
#  'cover',
#  'fabrication',
#  'substrate',
#  'flat',
#  'panel',
#  'cover',
#  'manufacture',
#  'glass',
#  'assembly',
#  'printed',
#  'circuit',
#  'board',
#  'electronic',
#  'component',
#  'onto',
#  'flat',
#  'panel',
#  'expression',
#  '“',
#  'flat',
#  'panel',
#  'display',
#  '”',
#  'cover',
#  'cathode-ray',
#  'tube',
#  'technology',
#  'c',
#  '84.86',
#  'also',
#  'includes',
#  'machine',
#  'apparatus',
#  'solely',
#  'principally',
#  'kind',
#  'used',
#  'manufacture',
#  'repair',
#  'mask',
#  'reticle',
#  'ii',
#  'assembling',
#  'semiconductor',
#  'device',
#  'electronic',
#  'integrated',
#  'circuit',
#  'iii',
#  'lifting',
#  'handling',
#  'loading',
#  'unloading',
#  'boule',
#  'wafer',
#  'semiconductor',
#  'device',
#  'electronic',
#  'integrated',
#  'circuit',
#  'flat',
#  'panel',
#  'display',
#  'subject',
#  'note',
#  '1',
#  'section',
#  'xvi',
#  'note',
#  '1',
#  '84',
#  'machine',
#  'apparatus',
#  'answering',
#  'description',
#  '84.86',
#  'classified',
#  'nomenclature',
#  '°',
#  '°',
#  '°',
#  'subheading',
#  'note',
#  '1.-',
#  'purpose',
#  'subheading',
#  '8465.20',
#  'term',
#  '“',
#  'machining',
#  'centre',
#  '”',
#  'applies',
#  'machine-tools',
#  'working',
#  'wood',
#  'cork',
#  'bone',
#  'hard',
#  'rubber',
#  'hard',
#  'plastic',
#  'similar',
#  'hard',
#  'material',
#  'carry',
#  'different',
#  'type',
#  'machining',
#  'operation',
#  'automatic',
#  'tool',
#  'change',
#  'magazine',
#  'like',
#  'conformity',
#  'machining',
#  'programme',
#  '2.-',
#  'purpose',
#  'subheading',
#  '8471.49',
#  'term',
#  '“',
#  'system',
#  '”',
#  'mean',
#  'automatic',
#  'data',
#  'processing',
#  'machine',
#  'whose',
#  'unit',
#  'satisfy',
#  'condition',
#  'laid',
#  'note',
#  '6',
#  'c',
#  '84',
#  'comprise',
#  'least',
#  'central',
#  'processing',
#  'unit',
#  'one',
#  'input',
#  'unit',
#  'example',
#  'keyboard',
#  'scanner',
#  'one',
#  'output',
#  'unit',
#  'example',
#  'visual',
#  'display',
#  'unit',
#  'printer',
#  '3.-',
#  'purpose',
#  'subheading',
#  '8481.20',
#  'expression',
#  '“',
#  'valve',
#  'oleohydraulic',
#  'pneumatic',
#  'transmission',
#  '”',
#  'mean',
#  'valve',
#  'used',
#  'specifically',
#  'transmission',
#  '“',
#  'fluid',
#  'power',
#  '”',
#  'hydraulic',
#  'pneumatic',
#  'system',
#  'energy',
#  'source',
#  'supplied',
#  'form',
#  'pressurised',
#  'fluid',
#  'liquid',
#  'gas',
#  'valve',
#  'may',
#  'type',
#  'example',
#  'pressure-reducing',
#  'type',
#  'check',
#  'type',
#  'subheading',
#  '8481.20',
#  'take',
#  'precedence',
#  'subheading',
#  '84.81',
#  '4.-',
#  'subheading',
#  '8482.40',
#  'applies',
#  'bearing',
#  'cylindrical',
#  'roller',
#  'uniform',
#  'diameter',
#  'exceeding',
#  '5',
#  'mm',
#  'length',
#  'least',
#  'three',
#  'time',
#  'diameter',
#  'end',
#  'roller',
#  'may',
#  'rounded',
#  'general',
#  'general',
#  'content',
#  'subject',
#  'provision',
#  'general',
#  'explanatory',
#  'note',
#  'section',
#  'xvi',
#  'cover',
#  'machinery',
#  'mechanical',
#  'appliance',
#  'part',
#  'thereof',
#  'specifically',
#  'covered',
#  '85',
#  'article',
#  'textile',
#  'material',
#  'technical',
#  'us',
#  '59.11',
#  'b',
#  'article',
#  'stone',
#  'etc.',
#  '68',
#  'c',
#  'ceramic',
#  'article',
#  '69',
#  'laboratory',
#  'glassware',
#  '70.17',
#  'machinery',
#  'appliance',
#  'part',
#  'thereof',
#  'glass',
#  '70.19',
#  '70.20',
#  'e',
#  'stove',
#  'central',
#  'heating',
#  'radiator',
#  'good',
#  '73.21',
#  '73.22',
#  'similar',
#  'article',
#  'base',
#  'metal',
#  'f',
#  'electro-mechanical',
#  'domestic',
#  'appliance',
#  '85.09',
#  'digital',
#  'camera',
#  '85.25',
#  'g',
#  'radiator',
#  'article',
#  'section',
#  'xvii',
#  'section',
#  'xvii',
#  'h',
#  'hand-operated',
#  'mechanical',
#  'floor',
#  'sweeper',
#  'motorised',
#  '96.03',
#  'general',
#  '84',
#  'cover',
#  'machinery',
#  'mechanical',
#  'apparatus',
#  '85',
#  'electrical',
#  'good',
#  'however',
#  'certain',
#  'machine',
#  'specified',
#  'heading',
#  ...]

# %%
import collections
ex_counter = collections.Counter(token_list)
print(ex_counter)
# Out:
# Counter({'machine': 65, 'note': 31, 'classified': 27, 'machinery': 26, 'heading': 25, 'processing': 23, 'cover': 22, 'apparatus': 22, 'material': 20, 'data': 19, 'part': 18, 'automatic': 18, 'purpose': 18, 'appliance': 16, 'article': 16, 'unit': 16, 'section': 14, '“': 14, '”': 14, 'used': 14, '1': 14, 'ceramic': 13, 'c': 12, 'device': 12, 'function': 12, 'e.g.': 12, 'example': 11, '2': 11, '84': 10, 'mechanical': 10, 'glass': 10, 'xvi': 10, 'description': 10, 'textile': 10, 'incorporating': 10, 'electronic': 10, 'one': 9, 'general': 9, 'electrical': 9, 'b': 8, 'metal': 8, 'subject': 8, '84.24': 8, '84.86': 8, 'applies': 8, 'flat': 8, 'also': 8, 'semiconductor': 8, 'covered': 8, 'e': 7, '3': 7, 'working': 7, 'expression': 7, 'following': 7, 'specific': 7, 'panel': 7, 'component': 7, 'subheading': 7, 'good': 7, 'certain': 7, 'thereof': 6, 'pump': 6, 'laboratory': 6, '84.01': 6, 'even': 6, 'machining': 6, 'use': 6, 'ii': 6, 'system': 6, '85': 6, 'circuit': 6, 'industry': 6, 'similar': 5, 'camera': 5, 'case': 5, 'designed': 5, 'different': 5, 'type': 5, '84.71': 5, 'iii': 5, 'performing': 5, 'solely': 5, 'principally': 5, '6': 5, 'mm': 5, 'integrated': 5, 'display': 5, 'valve': 5, 'etc.': 5, '4': 5, 'glassware': 4, 'digital': 4, 'operation': 4, '11': 4, 'group': 4, 'may': 4, '84.19': 4, 'however': 4, 'plant': 4, 'change': 4, '84.56': 4, 'head': 4, 'line': 4, 'mean': 4, 'program': 4, 'accordance': 4, 'specified': 4, 'condition': 4, 'kind': 4, 'central': 4, 'separately': 4, 'presented': 4, 'conjunction': 4, 'diameter': 4, 'principal': 4, 'manufacture': 4, 'electric': 4, 'motor': 4, 'electro-magnetic': 4, 'reference': 4, 'field': 4, 'although': 4, 'nuclear': 3, 'reactor': 3, 'boiler': 3, '69': 3, '70.17': 3, '70.19': 3, '70.20': 3, 'electro-mechanical': 3, 'domestic': 3, 'radiator': 3, 'xvii': 3, 'time': 3, 'ⅰ': 3, 'ⅱ': 3, 'yarn': 3, 'made': 3, 'equipment': 3, 'necessary': 3, '84.22': 3, 'printing': 3, 'machine-tools': 3, 'centre': 3, 'like': 3, 'least': 3, 'form': 3, 'transmission': 3, 'classification': 3, 'described': 3, 'unless': 3, '84.79': 3, 'combination': 3, 'term': 3, 'plastic': 3, 'answering': 3, 'nomenclature': 3, 'lifting': 3, '°': 3, 'hard': 3, '5': 3, 'explanatory': 3, 'heating': 3, 'hand': 3, 'particular': 3, 'moulding': 3, 'regard': 3, 'fall': 3, 'two': 3, 'principle': 3, 'potentially': 3, 'fact': 3, 'later': 3, '1.-': 2, '68': 2, 'technical': 2, 'us': 2, '73.21': 2, '73.22': 2, 'base': 2, 'chapter': 2, 'f': 2, '85.09': 2, '85.25': 2, 'g': 2, 'h': 2, 'hand-operated': 2, 'floor': 2, 'sweeper': 2, 'motorised': 2, '96.03': 2, '2.-': 2, 'answer': 2, '84.25': 2, '84.80': 2, 'appropriate': 2, 'germination': 2, 'incubator': 2, 'brooder': 2, '84.36': 2, 'grain': 2, 'dampening': 2, '84.37': 2, 'diffusing': 2, 'sugar': 2, 'juice': 2, 'extraction': 2, '84.38': 2, 'heat-treatment': 2, 'fabric': 2, '84.51': 2, 'temperature': 2, 'subsidiary': 2, 'sewing': 2, 'closing': 2, '84.52': 2, '84.72': 2, 'ink-jet': 2, '84.43': 2, 'water-jet': 2, 'cutting': 2, '3.-': 2, '84.57': 2, '4.-': 2, 'lathe': 2, 'including': 2, 'carry': 2, 'either': 2, 'tool': 2, 'magazine': 2, 'conformity': 2, 'programme': 2, 'workpiece': 2, 'transfer': 2, 'product': 2, 'composed': 2, 'uncoiler': 2, 'coil': 2, 'flattener': 2, 'execution': 2, 'user': 2, 'iv': 2, 'without': 2, 'requires': 2, 'consisting': 2, 'number': 2, 'paragraph': 2, 'meet': 2, 'keyboard': 2, 'input': 2, 'satisfy': 2, 'printer': 2, 'reception': 2, 'network': 2, 'television': 2, 'residual': 2, 'steel': 2, 'ball': 2, 'x': 2, '84.85': 2, 'addition': 2, '12': 2, 'diode': 2, 'boule': 2, 'wafer': 2, '8481.20': 2, 'pneumatic': 2, 'specifically': 2, 'fluid': 2, 'precedence': 2, '84.81': 2, 'roller': 2, 'provision': 2, 'steam': 2, 'calender': 2, 'press': 2, 'element': 2, 'operated': 2, 'electro-': 2, 'magnetic': 2, 'crane': 2, 'chuck': 2, 'control': 2, 'follows': 2, 'character': 2, 'rule': 2, 'high': 2, 'proportion': 2, 'incorporated': 2, 'regardless': 2, 'exception': 2, 'box': 2, 'mould': 2, '8': 2, 'see': ...

# %%
tags = ex_counter.most_common(100)

# %%
###WordCloud(워드크라우드) 만들기###
word_cloud = WordCloud(background_color ='white', colormap='Set1', max_font_size=300).generate_from_frequencies(dict(tags))

# 사이즈 설정 및 화면에 출력
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
plt.imshow(word_cloud)
plt.axis('off')

plt.show()

# %% [markdown]
# # 85류 해설서

# %%
import pandas as pd

text2 = open('./생성데이터/Chapter 85.txt', encoding='utf-8').read()
text2
# Out:
# 'Chapter 85\n\nElectrical machinery and equipment and parts thereof;\n\nsound recorders and reproducers,\n\ntelevision image and sound recorders and reproducers, and\n\nparts and accessories of such articles\n\nNotes.\n\n1. This Chapter does not cover :\n\n(a) Electrically warmed blankets, bed pads, foot muffs or the like; electrically warmed clothing, footwear or ear pads or other electrically warmed articles worn on or about the person;\n\n(b) Articles of glass of heading 70.11;\n\n(c) Machines and apparatus of heading 84.86;\n\n(d) Vacuum apparatus of a kind used in medical, surgical, dental or veterinary sciences (heading 90.18); or\n\n(e) Electrically heated furniture of Chapter 94.\n\n2. Headings 85.01 to 85.04 do not apply to goods described in heading 85.11, 85.12, 85.40, 85.41 or 85.42.\n\nHowever, metal tank mercury arc rectifiers remain classified in heading 85.04.\n\n3.- For the purposes of heading 85.07, the expression “electric accumulators” includes those presented with ancillary components which contribute to the accumulator’s function of storing and supplying energy or protect it from damage, such as electrical connectors, temperature control devices (for example, thermistors) and circuit protection devices. They may also include a portion of the protective housing of the goods in which they are to be used.\n\n4. Heading 85.09 covers only the following electro mechanical machines of the kind commonly used for domestic purposes :\n\n(a) Floor polishers, food grinders and mixers, and fruit or vegetable juice extractors, of any weight;\n\n(b) Other machines provided the weight of such machines does not exceed 20 kg.\n\nThe heading does not, however, apply to fans or ventilating or recycling hoods incorporating a fan, whether or not fitted with filters (heading 84.14), centrifugal clothes-dryers (heading 84.21), dish washing machines (heading 84.22), household washing machines (heading 84.50), roller or other ironing machines (heading 84.20 or 84.51), sewing machines (heading 84.52), electric scissors (heading 84.67) or to electrothermic appliances (heading 85.16).\n\n5. For the purposes of heading 85.17, the term “smartphones” means telephones for cellular networks, equipped with a mobile operating system designed to perform the functions of an automatic data processing machine such as downloading and running multiple applications simultaneously, including third-party applications, and whether or not integrating other features such as digital cameras and navigational aid systems.\n\n6. For the purposes of heading 85.23 :\n\n(a) “Solid-state non-volatile storage devices” (for example, “flash memory cards” or “flash electronic storage cards”) are storage devices with a connecting socket, comprising in the same housing one or more flash memories (for example, “FLASH E2PROM”) in the form of integrated circuits mounted on a printed circuit board. They may include a controller in the form of an integrated circuit and discrete passive components, such as capacitors and resistors;\n\n(b) The term “smart cards” means cards which have embedded in them one or more electronic integrated circuits (a microprocessor, random access memory (RAM) or read-only memory (ROM)) in the form of chips. These cards may contain contacts, a magnetic stripe or an embedded antenna but do not contain any other active or passive circuit elements.\n\n7. For the purposes of heading 85.24, “flat panel display modules” refer to devices or apparatus for the display of information, equipped at a minimum with a display screen, which are designed to be incorporated into articles of other headings prior to use. Display screens for flat panel display modules include, but are not limited to, those which are flat, curved, flexible, foldable or stretchable in form. Flat panel display modules may incorporate additional elements, including those necessary for receiving video signals and the allocation of those signals to pixels on the display. However, heading ...

# %%
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
from nltk.stem import WordNetLemmatizer
import nltk
import string

lemmar = WordNetLemmatizer()
stopwords = nltk.corpus.stopwords.words('english')
string = string.punctuation
for stri in string:
    stopwords.append(stri)

stopwords.append('heading')
stopwords.append('chapter')
stopwords.append('“')
stopwords.append('”')
words2 = word_tokenize(text2.lower())
print(words2)
# Out:
# ['chapter', '85', 'electrical', 'machinery', 'and', 'equipment', 'and', 'parts', 'thereof', ';', 'sound', 'recorders', 'and', 'reproducers', ',', 'television', 'image', 'and', 'sound', 'recorders', 'and', 'reproducers', ',', 'and', 'parts', 'and', 'accessories', 'of', 'such', 'articles', 'notes', '.', '1.', 'this', 'chapter', 'does', 'not', 'cover', ':', '(', 'a', ')', 'electrically', 'warmed', 'blankets', ',', 'bed', 'pads', ',', 'foot', 'muffs', 'or', 'the', 'like', ';', 'electrically', 'warmed', 'clothing', ',', 'footwear', 'or', 'ear', 'pads', 'or', 'other', 'electrically', 'warmed', 'articles', 'worn', 'on', 'or', 'about', 'the', 'person', ';', '(', 'b', ')', 'articles', 'of', 'glass', 'of', 'heading', '70.11', ';', '(', 'c', ')', 'machines', 'and', 'apparatus', 'of', 'heading', '84.86', ';', '(', 'd', ')', 'vacuum', 'apparatus', 'of', 'a', 'kind', 'used', 'in', 'medical', ',', 'surgical', ',', 'dental', 'or', 'veterinary', 'sciences', '(', 'heading', '90.18', ')', ';', 'or', '(', 'e', ')', 'electrically', 'heated', 'furniture', 'of', 'chapter', '94', '.', '2.', 'headings', '85.01', 'to', '85.04', 'do', 'not', 'apply', 'to', 'goods', 'described', 'in', 'heading', '85.11', ',', '85.12', ',', '85.40', ',', '85.41', 'or', '85.42.', 'however', ',', 'metal', 'tank', 'mercury', 'arc', 'rectifiers', 'remain', 'classified', 'in', 'heading', '85.04', '.', '3.-', 'for', 'the', 'purposes', 'of', 'heading', '85.07', ',', 'the', 'expression', '“', 'electric', 'accumulators', '”', 'includes', 'those', 'presented', 'with', 'ancillary', 'components', 'which', 'contribute', 'to', 'the', 'accumulator', '’', 's', 'function', 'of', 'storing', 'and', 'supplying', 'energy', 'or', 'protect', 'it', 'from', 'damage', ',', 'such', 'as', 'electrical', 'connectors', ',', 'temperature', 'control', 'devices', '(', 'for', 'example', ',', 'thermistors', ')', 'and', 'circuit', 'protection', 'devices', '.', 'they', 'may', 'also', 'include', 'a', 'portion', 'of', 'the', 'protective', 'housing', 'of', 'the', 'goods', 'in', 'which', 'they', 'are', 'to', 'be', 'used', '.', '4.', 'heading', '85.09', 'covers', 'only', 'the', 'following', 'electro', 'mechanical', 'machines', 'of', 'the', 'kind', 'commonly', 'used', 'for', 'domestic', 'purposes', ':', '(', 'a', ')', 'floor', 'polishers', ',', 'food', 'grinders', 'and', 'mixers', ',', 'and', 'fruit', 'or', 'vegetable', 'juice', 'extractors', ',', 'of', 'any', 'weight', ';', '(', 'b', ')', 'other', 'machines', 'provided', 'the', 'weight', 'of', 'such', 'machines', 'does', 'not', 'exceed', '20', 'kg', '.', 'the', 'heading', 'does', 'not', ',', 'however', ',', 'apply', 'to', 'fans', 'or', 'ventilating', 'or', 'recycling', 'hoods', 'incorporating', 'a', 'fan', ',', 'whether', 'or', 'not', 'fitted', 'with', 'filters', '(', 'heading', '84.14', ')', ',', 'centrifugal', 'clothes-dryers', '(', 'heading', '84.21', ')', ',', 'dish', 'washing', 'machines', '(', 'heading', '84.22', ')', ',', 'household', 'washing', 'machines', '(', 'heading', '84.50', ')', ',', 'roller', 'or', 'other', 'ironing', 'machines', '(', 'heading', '84.20', 'or', '84.51', ')', ',', 'sewing', 'machines', '(', 'heading', '84.52', ')', ',', 'electric', 'scissors', '(', 'heading', '84.67', ')', 'or', 'to', 'electrothermic', 'appliances', '(', 'heading', '85.16', ')', '.', '5.', 'for', 'the', 'purposes', 'of', 'heading', '85.17', ',', 'the', 'term', '“', 'smartphones', '”', 'means', 'telephones', 'for', 'cellular', 'networks', ',', 'equipped', 'with', 'a', 'mobile', 'operating', 'system', 'designed', 'to', 'perform', 'the', 'functions', 'of', 'an', 'automatic', 'data', 'processing', 'machine', 'such', 'as', 'downloading', 'and', 'running', 'multiple', 'applications', 'simultaneously', ',', 'including', 'third-party', 'applications', ',', 'and', 'whether', 'or', 'not', 'integrating', 'other', 'features', 'such', 'as', 'digital', 'cameras', 'and', 'navigational', 'aid', 'systems', '.', '6.', 'for', 'the', 'purposes', 'of', 'heading', '85.23', ':', '(', 'a',  ...

# %%
word_list2 = []

for word in words2:
    if word not in stopwords:
        word_list2.append(word)

word_list2
# Out:
# ['85',
#  'electrical',
#  'machinery',
#  'equipment',
#  'parts',
#  'thereof',
#  'sound',
#  'recorders',
#  'reproducers',
#  'television',
#  'image',
#  'sound',
#  'recorders',
#  'reproducers',
#  'parts',
#  'accessories',
#  'articles',
#  'notes',
#  '1.',
#  'cover',
#  'electrically',
#  'warmed',
#  'blankets',
#  'bed',
#  'pads',
#  'foot',
#  'muffs',
#  'like',
#  'electrically',
#  'warmed',
#  'clothing',
#  'footwear',
#  'ear',
#  'pads',
#  'electrically',
#  'warmed',
#  'articles',
#  'worn',
#  'person',
#  'b',
#  'articles',
#  'glass',
#  '70.11',
#  'c',
#  'machines',
#  'apparatus',
#  '84.86',
#  'vacuum',
#  'apparatus',
#  'kind',
#  'used',
#  'medical',
#  'surgical',
#  'dental',
#  'veterinary',
#  'sciences',
#  '90.18',
#  'e',
#  'electrically',
#  'heated',
#  'furniture',
#  '94',
#  '2.',
#  'headings',
#  '85.01',
#  '85.04',
#  'apply',
#  'goods',
#  'described',
#  '85.11',
#  '85.12',
#  '85.40',
#  '85.41',
#  '85.42.',
#  'however',
#  'metal',
#  'tank',
#  'mercury',
#  'arc',
#  'rectifiers',
#  'remain',
#  'classified',
#  '85.04',
#  '3.-',
#  'purposes',
#  '85.07',
#  'expression',
#  'electric',
#  'accumulators',
#  'includes',
#  'presented',
#  'ancillary',
#  'components',
#  'contribute',
#  'accumulator',
#  '’',
#  'function',
#  'storing',
#  'supplying',
#  'energy',
#  'protect',
#  'damage',
#  'electrical',
#  'connectors',
#  'temperature',
#  'control',
#  'devices',
#  'example',
#  'thermistors',
#  'circuit',
#  'protection',
#  'devices',
#  'may',
#  'also',
#  'include',
#  'portion',
#  'protective',
#  'housing',
#  'goods',
#  'used',
#  '4.',
#  '85.09',
#  'covers',
#  'following',
#  'electro',
#  'mechanical',
#  'machines',
#  'kind',
#  'commonly',
#  'used',
#  'domestic',
#  'purposes',
#  'floor',
#  'polishers',
#  'food',
#  'grinders',
#  'mixers',
#  'fruit',
#  'vegetable',
#  'juice',
#  'extractors',
#  'weight',
#  'b',
#  'machines',
#  'provided',
#  'weight',
#  'machines',
#  'exceed',
#  '20',
#  'kg',
#  'however',
#  'apply',
#  'fans',
#  'ventilating',
#  'recycling',
#  'hoods',
#  'incorporating',
#  'fan',
#  'whether',
#  'fitted',
#  'filters',
#  '84.14',
#  'centrifugal',
#  'clothes-dryers',
#  '84.21',
#  'dish',
#  'washing',
#  'machines',
#  '84.22',
#  'household',
#  'washing',
#  'machines',
#  '84.50',
#  'roller',
#  'ironing',
#  'machines',
#  '84.20',
#  '84.51',
#  'sewing',
#  'machines',
#  '84.52',
#  'electric',
#  'scissors',
#  '84.67',
#  'electrothermic',
#  'appliances',
#  '85.16',
#  '5.',
#  'purposes',
#  '85.17',
#  'term',
#  'smartphones',
#  'means',
#  'telephones',
#  'cellular',
#  'networks',
#  'equipped',
#  'mobile',
#  'operating',
#  'system',
#  'designed',
#  'perform',
#  'functions',
#  'automatic',
#  'data',
#  'processing',
#  'machine',
#  'downloading',
#  'running',
#  'multiple',
#  'applications',
#  'simultaneously',
#  'including',
#  'third-party',
#  'applications',
#  'whether',
#  'integrating',
#  'features',
#  'digital',
#  'cameras',
#  'navigational',
#  'aid',
#  'systems',
#  '6.',
#  'purposes',
#  '85.23',
#  'solid-state',
#  'non-volatile',
#  'storage',
#  'devices',
#  'example',
#  'flash',
#  'memory',
#  'cards',
#  'flash',
#  'electronic',
#  'storage',
#  'cards',
#  'storage',
#  'devices',
#  'connecting',
#  'socket',
#  'comprising',
#  'housing',
#  'one',
#  'flash',
#  'memories',
#  'example',
#  'flash',
#  'e2prom',
#  'form',
#  'integrated',
#  'circuits',
#  'mounted',
#  'printed',
#  'circuit',
#  'board',
#  'may',
#  'include',
#  'controller',
#  'form',
#  'integrated',
#  'circuit',
#  'discrete',
#  'passive',
#  'components',
#  'capacitors',
#  'resistors',
#  'b',
#  'term',
#  'smart',
#  'cards',
#  'means',
#  'cards',
#  'embedded',
#  'one',
#  'electronic',
#  'integrated',
#  'circuits',
#  'microprocessor',
#  'random',
#  'access',
#  'memory',
#  'ram',
#  'read-only',
#  'memory',
#  'rom',
#  'form',
#  'chips',
#  'cards',
#  'may',
#  'contain',
#  'contacts',
#  'magnetic',
#  'stripe',
#  'embedded',
#  'antenna',
#  'contain',
#  'active',
#  'passive',
#  'circuit',
#  'elements',
#  '7.',
#  'purposes',
#  '85.24',
#  'flat',
#  'panel',
#  'display',
#  'modules',
#  'refer',
#  'devices',
#  'apparatus',
#  'display',
#  'information',
#  'equipped',
#  'minimum',
#  'display',
#  'screen',
#  'designed',
#  'incorporated',
#  'articles',
#  'headings',
#  'prior',
#  'use',
#  'display',
#  'screens',
#  'flat',
#  'panel',
#  'display',
#  'modules',
#  'include',
#  'limited',
#  'flat',
#  'curved',
#  'flexible',
#  'foldable',
#  'stretchable',
#  'form',
#  'flat',
#  'panel',
#  'display',
#  'modules',
#  'may',
#  'incorporate',
#  'additional',
#  'elements',
#  'including',
#  'necessary',
#  'receiving',
#  'video',
#  'signals',
#  'allocation',
#  'signals',
#  'pixels',
#  'display',
#  'however',
#  '85.24',
#  'include',
#  'display',
#  'modules',
#  'equipped',
#  'components',
#  'converting',
#  'video',
#  'signals',
#  'e.g.',
#  'scaler',
#  'ic',
#  'decoder',
#  'ic',
#  'application',
#  'processer',
#  'otherwise',
#  'assumed',
#  'character',
#  'goods',
#  'headings',
#  'classification',
#  'flat',
#  'panel',
#  'display',
#  'modules',
#  'defined',
#  'note',
#  '85.24',
#  'shall',
#  'take',
#  'precedence',
#  'nomenclature',
#  '8.',
#  'purposes',
#  '85.34',
#  'printed',
#  'circuits',
#  'circuits',
#  'obtained',
#  'forming',
#  'insulating',
#  'base',
#  'printing',
#  'process',
#  'example',
#  'embossing',
#  'plating-up',
#  'etching',
#  'film',
#  'circuit',
#  'technique',
#  'conductor',
#  'elements',
#  'contacts',
#  'printed',
#  'components',
#  'example',
#  'inductances',
#  'resistors',
#  'capacitors',
#  'alone',
#  'interconnected',
#  'according',
#  'pre',
#  'established',
#  'pattern',
#  'elements',
#  'produce',
#  'rectify',
#  'modulate',
#  'amplify',
#  'electrical',
#  'signal',
#  'example',
#  'semiconductor',
#  'elements',
#  'expression',
#  'printed',
#  'circuits',
#  'cover',
#  'circuits',
#  'combined',
#  'elements',
#  'obtained',
#  'printing',
#  'process',
#  'cover',
#  'individual',
#  'discrete',
#  'resistors',
#  'capacitors',
#  'inductances',
#  'printed',
#  'circuits',
#  'may',
#  'however',
#  'fitted',
#  'non',
#  'printed',
#  'connecting',
#  'elements',
#  'thin-',
#  'thick-film',
#  'circuits',
#  'comprising',
#  'passive',
#  'active',
#  'elements',
#  'obtained',
#  'technological',
#  'process',
#  'classified',
#  '85.42',
#  '9.',
#  'purpose',
#  '85.36',
#  'connectors',
#  'optical',
#  'fibres',
#  'optical',
#  'fibre',
#  'bundles',
#  'cables',
#  'means',
#  'connectors',
#  'simply',
#  'mechanically',
#  'align',
#  'optical',
#  'fibres',
#  'end',
#  'end',
#  'digital',
#  'line',
#  'system',
#  'perform',
#  'function',
#  'amplification',
#  'regeneration',
#  'modification',
#  'signal',
#  '10.',
#  '85.37',
#  'include',
#  'cordless',
#  'infrared',
#  'devices',
#  'remote',
#  'control',
#  'television',
#  'receivers',
#  'electrical',
#  'equipment',
#  '85.43',
#  '11.',
#  'purposes',
#  '85.39',
#  'expression',
#  'light-emitting',
#  'diode',
#  'led',
#  'light',
#  'sources',
#  'covers',
#  'light-emitting',
#  'diode',
#  'led',
#  'modules',
#  'electrical',
#  'light',
#  'sources',
#  'based',
#  'light-emitting',
#  'diodes',
#  'led',
#  'arranged',
#  'electrical',
#  'circuits',
#  'containing',
#  'elements',
#  'like',
#  'electrical',
#  'mechanical',
#  'thermal',
#  'optical',
#  'elements',
#  'also',
#  'contain',
#  'discrete',
#  'active',
#  'elements',
#  'discrete',
#  'passive',
#  'elements',
#  'articles',
#  '85.36',
#  '85.42',
#  'purposes',
#  'providing',
#  'power',
#  'supply',
#  'power',
#  'control',
#  'light-emitting',
#  'diode',
#  'led',
#  'modules',
#  'cap',
#  'designed',
#  'allow',
#  'easy',
#  'installation',
#  'replacement',
#  'luminaire',
#  'ensure',
#  'mechanical',
#  'electrical',
#  'contact',
#  'b',
#  'light-emitting',
#  'diode',
#  'led',
#  'lamps',
#  'electrical',
#  'light',
#  'sources',
#  'containing',
#  'one',
#  'led',
#  'modules',
#  'containing',
#  'elements',
#  'like',
#  'electrical',
#  'mechanical',
#  'thermal',
#  'optical',
#  'elements',
#  'distinction',
#  'light-emitting',
#  'diode',
#  'led',
#  'modules',
#  'light-emitting',
#  'diode',
#  'led',
#  'lamps',
#  'lamps',
#  'cap',
#  'designed',
#  'allow',
#  'easy',
#  'installation',
#  'replacement',
#  'luminaire',
#  'ensure',
#  'mechanical',
#  'electrical',
#  'contact',
#  '12.',
#  'purposes',
#  'headings',
#  '85.41',
#  '85.42',
#  'semiconductor',
#  'devices',
#  'semiconductor',
#  'devices',
#  'operation',
#  'depends',
#  'variations',
#  'resistivity',
#  'application',
#  'electric',
#  'field',
#  'semiconductor-based',
#  'transducers',
#  'semiconductor',
#  'devices',
#  'may',
#  'also',
#  'include',
#  'assembly',
#  'plural',
#  'elements',
#  'whether',
#  'equipped',
#  'active',
#  'passive',
#  'device',
#  'ancillary',
#  'functions',
#  'semiconductor-based',
#  'transducers',
#  'purposes',
#  'definition',
#  'semiconductor-based',
#  'sensors',
#  'semiconductor-based',
#  'actuators',
#  'semiconductor-based',
#  'resonators',
#  'semiconductor-based',
#  'oscillators',
#  'types',
#  'discrete',
#  'semiconductor-based',
#  'devices',
#  'perform',
#  'intrinsic',
#  'function',
#  'able',
#  'convert',
#  'kind',
#  'physical',
#  'chemical',
#  'phenomena',
#  'action',
#  'electrical',
#  'signal',
#  'electrical',
#  'signal',
#  'type',
#  'physical',
#  'phenomenon',
#  'action',
#  'elements',
#  'semiconductor-based',
#  'transducers',
#  'indivisibly',
#  'combined',
#  'may',
#  'also',
#  'include',
#  'necessary',
#  'materials',
#  'indivisibly',
#  'attached',
#  'enable',
#  'construction',
#  'function',
#  'following',
#  'expressions',
#  'mean',
#  '1',
#  'semiconductor-based',
#  'means',
#  'built',
#  'manufactured',
#  'semiconductor',
#  'substrate',
#  'made',
#  'semiconductor',
#  'materials',
#  'manufactured',
#  'semiconductor',
#  'technology',
#  'semiconductor',
#  'substrate',
#  'material',
#  'plays',
#  'critical',
#  'unreplaceable',
#  'role',
#  'transducer',
#  'function',
#  'performance',
#  'operation',
#  'based',
#  'semiconductor',
#  'properties',
#  'including',
#  'physical',
#  'electrical',
#  'chemical',
#  'optical',
#  'properties',
#  '2',
#  'physical',
#  'chemical',
#  'phenomena',
#  'relate',
#  'phenomena',
#  'pressure',
#  'acoustic',
#  'waves',
#  'acceleration',
#  'vibration',
#  'movement',
#  'orientation',
#  'strain',
#  'magnetic',
#  'field',
#  'strength',
#  'electric',
#  'field',
#  'strength',
#  'light',
#  'radioactivity',
#  'humidity',
#  'flow',
#  'chemicals',
#  'concentration',
#  'etc',
#  '3',
#  'semiconductor-based',
#  'sensor',
#  'type',
#  'semiconductor',
#  'device',
#  'consists',
#  'microelectronic',
#  'mechanical',
#  'structures',
#  'created',
#  'mass',
#  'surface',
#  'semiconductor',
#  'function',
#  'detecting',
#  'physical',
#  'chemical',
#  'quantities',
#  'converting',
#  'electric',
#  'signals',
#  'caused',
#  'resulting',
#  'variations',
#  'electric',
#  'properties',
#  'displacement',
#  'mechanical',
#  'structure',
#  '4',
#  'semiconductor-based',
#  'actuator',
#  'type',
#  'semiconductor',
#  'device',
#  'consists',
#  'microelectronic',
#  'mechanical',
#  'structures',
#  'created',
#  'mass',
#  'surface',
#  'semiconductor',
#  'function',
#  'converting',
#  'electric',
#  'signals',
#  'physical',
#  'movement',
#  '5',
#  'semiconductor-based',
#  'resonator',
#  'type',
#  'semiconductor',
#  'device',
#  'consists',
#  'microelectronic',
#  'mechanical',
#  'structures',
#  'created',
#  'mass',
#  'surface',
#  'semiconductor',
#  'function',
#  'generating',
#  'mechanical',
#  'electrical',
#  'oscillation',
#  'predefined',
#  'frequency',
#  'depends',
#  'physical',
#  'geometry',
#  'structures',
#  'response',
#  'external',
#  'input',
#  '6',
#  'semiconductor-based',
#  'oscillator',
#  'type',
#  'semiconductor',
#  'device',
#  'consists',
#  'microelectronic',
#  'mechanical',
#  'structures',
#  'created',
#  'mass',
#  'surface',
#  'semiconductor',
#  'function',
#  'generating',
#  'mechanical',
#  'electrical',
#  'oscillation',
#  'predefined',
#  'frequency',
#  'depends',
#  'physical',
#  'geometry',
#  'structures',
#  'ⅱ',
#  'light-emitting',
#  'diodes',
#  'led',
#  'semiconductor',
#  'devices',
#  'based',
#  'semiconductor',
#  'materials',
#  'convert',
#  'electrical',
#  'energy',
#  'visible',
#  'infra-red',
#  'ultra-violet',
#  'rays',
#  'whether',
#  'electrically',
#  'connected',
#  'among',
#  'whether',
#  'combined',
#  'protective',
#  'diodes',
#  'light-emitting',
#  'diodes',
#  'led',
#  '85.41',
#  'incorporate',
#  'elements',
#  'purposes',
#  'providing',
#  'power',
#  'supply',
#  'power',
#  'control',
#  'b',
#  'electronic',
#  'integrated',
#  'circuits',
#  'monolithic',
#  'integrated',
#  'circuits',
#  'circuit',
#  'elements',
#  'diodes',
#  'transistors',
#  'resistors',
#  'capacitors',
#  'inductances',
#  'etc',
#  'created',
#  'mass',
#  'essentially',
#  'surface',
#  'semiconductor',
#  'compound',
#  'semiconductor',
#  'material',
#  'example',
#  'doped',
#  'silicon',
#  'gallium',
#  'arsenide',
#  'silicon',
#  'germanium',
#  'indium',
#  'phosphide',
#  'inseparably',
#  'associated',
#  'ii',
#  'hybrid',
#  'integrated',
#  'circuits',
#  'passive',
#  'elements',
#  'resistors',
#  'capacitors',
#  'inductances',
#  'etc',
#  'obtained',
#  'thin-',
#  'thick-film',
#  'technology',
#  'active',
#  'elements',
#  'diodes',
#  'transistors',
#  'monolithic',
#  'integrated',
#  'circuits',
#  'etc',
#  'obtained',
#  'semiconductor',
#  'technology',
#  'combined',
#  'intents',
#  'purposes',
#  'indivisibly',
#  'interconnections',
#  'interconnecting',
#  'cables',
#  'single',
#  'insulating',
#  'substrate',
#  'glass',
#  'ceramic',
#  'etc.',
#  'circuits',
#  'may',
#  'also',
#  'include',
#  'discrete',
#  'components',
#  'iii',
#  'multichip',
#  'integrated',
#  'circuits',
#  'consisting',
#  'two',
#  'interconnected',
#  'monolithic',
#  'integrated',
#  'circuits',
#  'combined',
#  'intents',
#  'purposes',
#  'indivisibly',
#  'whether',
#  'one',
#  'insulating',
#  'substrates',
#  'without',
#  'leadframes',
#  'active',
#  'passive',
#  ...]

# %%
token_list2 = [lemmar.lemmatize(w) for w in word_list2]
token_list2
# Out:
# ['85',
#  'electrical',
#  'machinery',
#  'equipment',
#  'part',
#  'thereof',
#  'sound',
#  'recorder',
#  'reproducer',
#  'television',
#  'image',
#  'sound',
#  'recorder',
#  'reproducer',
#  'part',
#  'accessory',
#  'article',
#  'note',
#  '1.',
#  'cover',
#  'electrically',
#  'warmed',
#  'blanket',
#  'bed',
#  'pad',
#  'foot',
#  'muff',
#  'like',
#  'electrically',
#  'warmed',
#  'clothing',
#  'footwear',
#  'ear',
#  'pad',
#  'electrically',
#  'warmed',
#  'article',
#  'worn',
#  'person',
#  'b',
#  'article',
#  'glass',
#  '70.11',
#  'c',
#  'machine',
#  'apparatus',
#  '84.86',
#  'vacuum',
#  'apparatus',
#  'kind',
#  'used',
#  'medical',
#  'surgical',
#  'dental',
#  'veterinary',
#  'science',
#  '90.18',
#  'e',
#  'electrically',
#  'heated',
#  'furniture',
#  '94',
#  '2.',
#  'heading',
#  '85.01',
#  '85.04',
#  'apply',
#  'good',
#  'described',
#  '85.11',
#  '85.12',
#  '85.40',
#  '85.41',
#  '85.42.',
#  'however',
#  'metal',
#  'tank',
#  'mercury',
#  'arc',
#  'rectifier',
#  'remain',
#  'classified',
#  '85.04',
#  '3.-',
#  'purpose',
#  '85.07',
#  'expression',
#  'electric',
#  'accumulator',
#  'includes',
#  'presented',
#  'ancillary',
#  'component',
#  'contribute',
#  'accumulator',
#  '’',
#  'function',
#  'storing',
#  'supplying',
#  'energy',
#  'protect',
#  'damage',
#  'electrical',
#  'connector',
#  'temperature',
#  'control',
#  'device',
#  'example',
#  'thermistor',
#  'circuit',
#  'protection',
#  'device',
#  'may',
#  'also',
#  'include',
#  'portion',
#  'protective',
#  'housing',
#  'good',
#  'used',
#  '4.',
#  '85.09',
#  'cover',
#  'following',
#  'electro',
#  'mechanical',
#  'machine',
#  'kind',
#  'commonly',
#  'used',
#  'domestic',
#  'purpose',
#  'floor',
#  'polisher',
#  'food',
#  'grinder',
#  'mixer',
#  'fruit',
#  'vegetable',
#  'juice',
#  'extractor',
#  'weight',
#  'b',
#  'machine',
#  'provided',
#  'weight',
#  'machine',
#  'exceed',
#  '20',
#  'kg',
#  'however',
#  'apply',
#  'fan',
#  'ventilating',
#  'recycling',
#  'hood',
#  'incorporating',
#  'fan',
#  'whether',
#  'fitted',
#  'filter',
#  '84.14',
#  'centrifugal',
#  'clothes-dryers',
#  '84.21',
#  'dish',
#  'washing',
#  'machine',
#  '84.22',
#  'household',
#  'washing',
#  'machine',
#  '84.50',
#  'roller',
#  'ironing',
#  'machine',
#  '84.20',
#  '84.51',
#  'sewing',
#  'machine',
#  '84.52',
#  'electric',
#  'scissors',
#  '84.67',
#  'electrothermic',
#  'appliance',
#  '85.16',
#  '5.',
#  'purpose',
#  '85.17',
#  'term',
#  'smartphones',
#  'mean',
#  'telephone',
#  'cellular',
#  'network',
#  'equipped',
#  'mobile',
#  'operating',
#  'system',
#  'designed',
#  'perform',
#  'function',
#  'automatic',
#  'data',
#  'processing',
#  'machine',
#  'downloading',
#  'running',
#  'multiple',
#  'application',
#  'simultaneously',
#  'including',
#  'third-party',
#  'application',
#  'whether',
#  'integrating',
#  'feature',
#  'digital',
#  'camera',
#  'navigational',
#  'aid',
#  'system',
#  '6.',
#  'purpose',
#  '85.23',
#  'solid-state',
#  'non-volatile',
#  'storage',
#  'device',
#  'example',
#  'flash',
#  'memory',
#  'card',
#  'flash',
#  'electronic',
#  'storage',
#  'card',
#  'storage',
#  'device',
#  'connecting',
#  'socket',
#  'comprising',
#  'housing',
#  'one',
#  'flash',
#  'memory',
#  'example',
#  'flash',
#  'e2prom',
#  'form',
#  'integrated',
#  'circuit',
#  'mounted',
#  'printed',
#  'circuit',
#  'board',
#  'may',
#  'include',
#  'controller',
#  'form',
#  'integrated',
#  'circuit',
#  'discrete',
#  'passive',
#  'component',
#  'capacitor',
#  'resistor',
#  'b',
#  'term',
#  'smart',
#  'card',
#  'mean',
#  'card',
#  'embedded',
#  'one',
#  'electronic',
#  'integrated',
#  'circuit',
#  'microprocessor',
#  'random',
#  'access',
#  'memory',
#  'ram',
#  'read-only',
#  'memory',
#  'rom',
#  'form',
#  'chip',
#  'card',
#  'may',
#  'contain',
#  'contact',
#  'magnetic',
#  'stripe',
#  'embedded',
#  'antenna',
#  'contain',
#  'active',
#  'passive',
#  'circuit',
#  'element',
#  '7.',
#  'purpose',
#  '85.24',
#  'flat',
#  'panel',
#  'display',
#  'module',
#  'refer',
#  'device',
#  'apparatus',
#  'display',
#  'information',
#  'equipped',
#  'minimum',
#  'display',
#  'screen',
#  'designed',
#  'incorporated',
#  'article',
#  'heading',
#  'prior',
#  'use',
#  'display',
#  'screen',
#  'flat',
#  'panel',
#  'display',
#  'module',
#  'include',
#  'limited',
#  'flat',
#  'curved',
#  'flexible',
#  'foldable',
#  'stretchable',
#  'form',
#  'flat',
#  'panel',
#  'display',
#  'module',
#  'may',
#  'incorporate',
#  'additional',
#  'element',
#  'including',
#  'necessary',
#  'receiving',
#  'video',
#  'signal',
#  'allocation',
#  'signal',
#  'pixel',
#  'display',
#  'however',
#  '85.24',
#  'include',
#  'display',
#  'module',
#  'equipped',
#  'component',
#  'converting',
#  'video',
#  'signal',
#  'e.g.',
#  'scaler',
#  'ic',
#  'decoder',
#  'ic',
#  'application',
#  'processer',
#  'otherwise',
#  'assumed',
#  'character',
#  'good',
#  'heading',
#  'classification',
#  'flat',
#  'panel',
#  'display',
#  'module',
#  'defined',
#  'note',
#  '85.24',
#  'shall',
#  'take',
#  'precedence',
#  'nomenclature',
#  '8.',
#  'purpose',
#  '85.34',
#  'printed',
#  'circuit',
#  'circuit',
#  'obtained',
#  'forming',
#  'insulating',
#  'base',
#  'printing',
#  'process',
#  'example',
#  'embossing',
#  'plating-up',
#  'etching',
#  'film',
#  'circuit',
#  'technique',
#  'conductor',
#  'element',
#  'contact',
#  'printed',
#  'component',
#  'example',
#  'inductance',
#  'resistor',
#  'capacitor',
#  'alone',
#  'interconnected',
#  'according',
#  'pre',
#  'established',
#  'pattern',
#  'element',
#  'produce',
#  'rectify',
#  'modulate',
#  'amplify',
#  'electrical',
#  'signal',
#  'example',
#  'semiconductor',
#  'element',
#  'expression',
#  'printed',
#  'circuit',
#  'cover',
#  'circuit',
#  'combined',
#  'element',
#  'obtained',
#  'printing',
#  'process',
#  'cover',
#  'individual',
#  'discrete',
#  'resistor',
#  'capacitor',
#  'inductance',
#  'printed',
#  'circuit',
#  'may',
#  'however',
#  'fitted',
#  'non',
#  'printed',
#  'connecting',
#  'element',
#  'thin-',
#  'thick-film',
#  'circuit',
#  'comprising',
#  'passive',
#  'active',
#  'element',
#  'obtained',
#  'technological',
#  'process',
#  'classified',
#  '85.42',
#  '9.',
#  'purpose',
#  '85.36',
#  'connector',
#  'optical',
#  'fibre',
#  'optical',
#  'fibre',
#  'bundle',
#  'cable',
#  'mean',
#  'connector',
#  'simply',
#  'mechanically',
#  'align',
#  'optical',
#  'fibre',
#  'end',
#  'end',
#  'digital',
#  'line',
#  'system',
#  'perform',
#  'function',
#  'amplification',
#  'regeneration',
#  'modification',
#  'signal',
#  '10.',
#  '85.37',
#  'include',
#  'cordless',
#  'infrared',
#  'device',
#  'remote',
#  'control',
#  'television',
#  'receiver',
#  'electrical',
#  'equipment',
#  '85.43',
#  '11.',
#  'purpose',
#  '85.39',
#  'expression',
#  'light-emitting',
#  'diode',
#  'led',
#  'light',
#  'source',
#  'cover',
#  'light-emitting',
#  'diode',
#  'led',
#  'module',
#  'electrical',
#  'light',
#  'source',
#  'based',
#  'light-emitting',
#  'diode',
#  'led',
#  'arranged',
#  'electrical',
#  'circuit',
#  'containing',
#  'element',
#  'like',
#  'electrical',
#  'mechanical',
#  'thermal',
#  'optical',
#  'element',
#  'also',
#  'contain',
#  'discrete',
#  'active',
#  'element',
#  'discrete',
#  'passive',
#  'element',
#  'article',
#  '85.36',
#  '85.42',
#  'purpose',
#  'providing',
#  'power',
#  'supply',
#  'power',
#  'control',
#  'light-emitting',
#  'diode',
#  'led',
#  'module',
#  'cap',
#  'designed',
#  'allow',
#  'easy',
#  'installation',
#  'replacement',
#  'luminaire',
#  'ensure',
#  'mechanical',
#  'electrical',
#  'contact',
#  'b',
#  'light-emitting',
#  'diode',
#  'led',
#  'lamp',
#  'electrical',
#  'light',
#  'source',
#  'containing',
#  'one',
#  'led',
#  'module',
#  'containing',
#  'element',
#  'like',
#  'electrical',
#  'mechanical',
#  'thermal',
#  'optical',
#  'element',
#  'distinction',
#  'light-emitting',
#  'diode',
#  'led',
#  'module',
#  'light-emitting',
#  'diode',
#  'led',
#  'lamp',
#  'lamp',
#  'cap',
#  'designed',
#  'allow',
#  'easy',
#  'installation',
#  'replacement',
#  'luminaire',
#  'ensure',
#  'mechanical',
#  'electrical',
#  'contact',
#  '12.',
#  'purpose',
#  'heading',
#  '85.41',
#  '85.42',
#  'semiconductor',
#  'device',
#  'semiconductor',
#  'device',
#  'operation',
#  'depends',
#  'variation',
#  'resistivity',
#  'application',
#  'electric',
#  'field',
#  'semiconductor-based',
#  'transducer',
#  'semiconductor',
#  'device',
#  'may',
#  'also',
#  'include',
#  'assembly',
#  'plural',
#  'element',
#  'whether',
#  'equipped',
#  'active',
#  'passive',
#  'device',
#  'ancillary',
#  'function',
#  'semiconductor-based',
#  'transducer',
#  'purpose',
#  'definition',
#  'semiconductor-based',
#  'sensor',
#  'semiconductor-based',
#  'actuator',
#  'semiconductor-based',
#  'resonator',
#  'semiconductor-based',
#  'oscillator',
#  'type',
#  'discrete',
#  'semiconductor-based',
#  'device',
#  'perform',
#  'intrinsic',
#  'function',
#  'able',
#  'convert',
#  'kind',
#  'physical',
#  'chemical',
#  'phenomenon',
#  'action',
#  'electrical',
#  'signal',
#  'electrical',
#  'signal',
#  'type',
#  'physical',
#  'phenomenon',
#  'action',
#  'element',
#  'semiconductor-based',
#  'transducer',
#  'indivisibly',
#  'combined',
#  'may',
#  'also',
#  'include',
#  'necessary',
#  'material',
#  'indivisibly',
#  'attached',
#  'enable',
#  'construction',
#  'function',
#  'following',
#  'expression',
#  'mean',
#  '1',
#  'semiconductor-based',
#  'mean',
#  'built',
#  'manufactured',
#  'semiconductor',
#  'substrate',
#  'made',
#  'semiconductor',
#  'material',
#  'manufactured',
#  'semiconductor',
#  'technology',
#  'semiconductor',
#  'substrate',
#  'material',
#  'play',
#  'critical',
#  'unreplaceable',
#  'role',
#  'transducer',
#  'function',
#  'performance',
#  'operation',
#  'based',
#  'semiconductor',
#  'property',
#  'including',
#  'physical',
#  'electrical',
#  'chemical',
#  'optical',
#  'property',
#  '2',
#  'physical',
#  'chemical',
#  'phenomenon',
#  'relate',
#  'phenomenon',
#  'pressure',
#  'acoustic',
#  'wave',
#  'acceleration',
#  'vibration',
#  'movement',
#  'orientation',
#  'strain',
#  'magnetic',
#  'field',
#  'strength',
#  'electric',
#  'field',
#  'strength',
#  'light',
#  'radioactivity',
#  'humidity',
#  'flow',
#  'chemical',
#  'concentration',
#  'etc',
#  '3',
#  'semiconductor-based',
#  'sensor',
#  'type',
#  'semiconductor',
#  'device',
#  'consists',
#  'microelectronic',
#  'mechanical',
#  'structure',
#  'created',
#  'mass',
#  'surface',
#  'semiconductor',
#  'function',
#  'detecting',
#  'physical',
#  'chemical',
#  'quantity',
#  'converting',
#  'electric',
#  'signal',
#  'caused',
#  'resulting',
#  'variation',
#  'electric',
#  'property',
#  'displacement',
#  'mechanical',
#  'structure',
#  '4',
#  'semiconductor-based',
#  'actuator',
#  'type',
#  'semiconductor',
#  'device',
#  'consists',
#  'microelectronic',
#  'mechanical',
#  'structure',
#  'created',
#  'mass',
#  'surface',
#  'semiconductor',
#  'function',
#  'converting',
#  'electric',
#  'signal',
#  'physical',
#  'movement',
#  '5',
#  'semiconductor-based',
#  'resonator',
#  'type',
#  'semiconductor',
#  'device',
#  'consists',
#  'microelectronic',
#  'mechanical',
#  'structure',
#  'created',
#  'mass',
#  'surface',
#  'semiconductor',
#  'function',
#  'generating',
#  'mechanical',
#  'electrical',
#  'oscillation',
#  'predefined',
#  'frequency',
#  'depends',
#  'physical',
#  'geometry',
#  'structure',
#  'response',
#  'external',
#  'input',
#  '6',
#  'semiconductor-based',
#  'oscillator',
#  'type',
#  'semiconductor',
#  'device',
#  'consists',
#  'microelectronic',
#  'mechanical',
#  'structure',
#  'created',
#  'mass',
#  'surface',
#  'semiconductor',
#  'function',
#  'generating',
#  'mechanical',
#  'electrical',
#  'oscillation',
#  'predefined',
#  'frequency',
#  'depends',
#  'physical',
#  'geometry',
#  'structure',
#  'ⅱ',
#  'light-emitting',
#  'diode',
#  'led',
#  'semiconductor',
#  'device',
#  'based',
#  'semiconductor',
#  'material',
#  'convert',
#  'electrical',
#  'energy',
#  'visible',
#  'infra-red',
#  'ultra-violet',
#  'ray',
#  'whether',
#  'electrically',
#  'connected',
#  'among',
#  'whether',
#  'combined',
#  'protective',
#  'diode',
#  'light-emitting',
#  'diode',
#  'led',
#  '85.41',
#  'incorporate',
#  'element',
#  'purpose',
#  'providing',
#  'power',
#  'supply',
#  'power',
#  'control',
#  'b',
#  'electronic',
#  'integrated',
#  'circuit',
#  'monolithic',
#  'integrated',
#  'circuit',
#  'circuit',
#  'element',
#  'diode',
#  'transistor',
#  'resistor',
#  'capacitor',
#  'inductance',
#  'etc',
#  'created',
#  'mass',
#  'essentially',
#  'surface',
#  'semiconductor',
#  'compound',
#  'semiconductor',
#  'material',
#  'example',
#  'doped',
#  'silicon',
#  'gallium',
#  'arsenide',
#  'silicon',
#  'germanium',
#  'indium',
#  'phosphide',
#  'inseparably',
#  'associated',
#  'ii',
#  'hybrid',
#  'integrated',
#  'circuit',
#  'passive',
#  'element',
#  'resistor',
#  'capacitor',
#  'inductance',
#  'etc',
#  'obtained',
#  'thin-',
#  'thick-film',
#  'technology',
#  'active',
#  'element',
#  'diode',
#  'transistor',
#  'monolithic',
#  'integrated',
#  'circuit',
#  'etc',
#  'obtained',
#  'semiconductor',
#  'technology',
#  'combined',
#  'intent',
#  'purpose',
#  'indivisibly',
#  'interconnection',
#  'interconnecting',
#  'cable',
#  'single',
#  'insulating',
#  'substrate',
#  'glass',
#  'ceramic',
#  'etc.',
#  'circuit',
#  'may',
#  'also',
#  'include',
#  'discrete',
#  'component',
#  'iii',
#  'multichip',
#  'integrated',
#  'circuit',
#  'consisting',
#  'two',
#  'interconnected',
#  'monolithic',
#  'integrated',
#  'circuit',
#  'combined',
#  'intent',
#  'purpose',
#  'indivisibly',
#  'whether',
#  'one',
#  'insulating',
#  'substrate',
#  'without',
#  'leadframes',
#  'active',
#  'passive',
#  ...]

# %%
import collections
ex_counter2 = collections.Counter(token_list2)
print(ex_counter2)
# Out:
# Counter({'electrical': 30, 'circuit': 29, 'semiconductor': 27, 'machine': 25, 'element': 21, 'mechanical': 19, 'purpose': 18, 'function': 18, 'device': 17, 'module': 16, 'integrated': 15, 'structure': 15, 'electric': 14, 'cover': 13, 'component': 13, 'diode': 13, 'semiconductor-based': 13, 'physical': 13, 'etc': 13, 'camera': 12, 'apparatus': 11, 'signal': 11, 'silicon': 11, 'part': 10, 'b': 10, 'classified': 10, 'display': 10, 'led': 10, 'article': 9, 'note': 9, 'example': 9, 'may': 9, 'light-emitting': 9, 'created': 9, 'mass': 9, 'surface': 9, 'heading': 8, 'include': 8, 'based': 8, 'chemical': 8, 'phenomenon': 8, 'material': 8, 'microelectronic': 8, 'subheading': 8, 'good': 7, 'appliance': 7, 'designed': 7, 'memory': 7, 'one': 7, 'printed': 7, 'discrete': 7, 'passive': 7, 'active': 7, 'video': 7, 'type': 7, 'property': 7, 'general': 7, 'certain': 7, 'equipment': 6, 'recorder': 6, 'electrically': 6, 'kind': 6, 'used': 6, '85.41': 6, 'however': 6, 'also': 6, 'whether': 6, 'mean': 6, 'including': 6, 'capacitor': 6, 'flat': 6, 'use': 6, 'insulating': 6, 'optical': 6, 'light': 6, 'television': 5, 'application': 5, 'digital': 5, 'card': 5, 'resistor': 5, 'panel': 5, 'e.g.': 5, 'obtained': 5, 'combined': 5, '85.42': 5, 'power': 5, 'depends': 5, 'field': 5, 'indivisibly': 5, 'substrate': 5, 'generating': 5, 'sound': 4, 'like': 4, 'glass': 4, '85.04': 4, 'expression': 4, 'accumulator': 4, 'control': 4, 'following': 4, 'equipped': 4, '85.23': 4, 'storage': 4, 'flash': 4, 'electronic': 4, 'form': 4, 'contact': 4, 'magnetic': 4, '85.24': 4, 'converting': 4, 'inductance': 4, 'non': 4, 'source': 4, 'lamp': 4, 'operation': 4, 'transducer': 4, 'sensor': 4, 'actuator': 4, 'resonator': 4, 'oscillator': 4, 'manufactured': 4, '2': 4, 'movement': 4, 'strength': 4, 'consists': 4, 'oscillation': 4, 'predefined': 4, 'frequency': 4, 'geometry': 4, 'monolithic': 4, 'without': 4, 'consist': 4, '84': 4, 'see': 4, 'section': 4, 'recording': 4, 'machinery': 3, 'thereof': 3, 'reproducer': 3, 'warmed': 3, 'pad': 3, 'c': 3, 'heated': 3, 'connector': 3, 'electro': 3, 'domestic': 3, 'fan': 3, 'system': 3, 'perform': 3, 'connecting': 3, 'contain': 3, 'process': 3, '85.36': 3, 'fibre': 3, 'containing': 3, 'thermal': 3, 'variation': 3, 'assembly': 3, 'convert': 3, '1': 3, 'technology': 3, '3': 3, '5': 3, 'external': 3, 'transistor': 3, 'intent': 3, 'single': 3, 'onto': 3, 'particular': 3, '°': 3, 'spent': 3, 'primary': 3, 'explanatory': 3, 'xvi': 3, 'suitable': 3, 'solely': 3, 'principally': 3, 'image': 2, 'accessory': 2, '1.': 2, 'medical': 2, '90.18': 2, '2.': 2, '85.01': 2, 'apply': 2, '85.11': 2, '85.40': 2, 'metal': 2, 'remain': 2, '85.07': 2, 'ancillary': 2, 'energy': 2, 'protective': 2, 'housing': 2, '4.': 2, '85.09': 2, 'weight': 2, 'exceed': 2, 'fitted': 2, '84.14': 2, 'washing': 2, '84.20': 2, '85.16': 2, '5.': 2, 'term': 2, 'operating': 2, 'automatic': 2, 'data': 2, 'processing': 2, 'comprising': 2, 'board': 2, 'embedded': 2, 'screen': 2, 'incorporate': 2, 'necessary': 2, 'ic': 2, 'classification': 2, 'defined': 2, 'shall': 2, 'take': 2, 'precedence': 2, 'nomenclature': 2, 'printing': 2, 'film': 2, 'interconnected': 2, 'individual': 2, 'thin-': 2, 'thick-film': 2, 'cable': 2, 'end': 2, '85.43': 2, '85.39': 2, 'providing': 2, 'supply': 2, 'cap': 2, 'allow': 2, 'easy': 2, 'installation': 2, 'replacement': 2, 'luminaire': 2, 'ensure': 2, 'definition': 2, 'action': 2, 'enable': 2, 'built': 2, 'made': 2, 'play': 2, 'role': 2, 'pressure': 2, 'acoustic': 2, 'wave': 2, 'acceleration': 2, 'vibration': 2, 'orientation': 2, 'strain': 2, 'radioactivity': 2, 'humidity': 2, 'flow': 2, 'concentration': 2, 'detecting': 2, 'caused': 2, 'resulting': 2, 'displacement': 2, '4': 2, 'response': 2, 'input': 2, '6': 2, 'visible': 2, 'ii': 2, 'hybrid': 2, 'ceramic': 2, 'etc.': 2, 'iii': 2, 'iv': 2, 'multi-component': 2, 'mcos': 2, 'combination': 2, 'least': 2, 'classifiable': 2, '85.32': 2, 'ball': 2, 'independently': 2, 'exceeding': 2, 'mm': 2, 'per': 2, '50': 2, 'frame': 2 ...

# %%
tags2 = ex_counter2.most_common(100)

# %%
###WordCloud(워드크라우드) 만들기###
word_cloud = WordCloud(background_color='white',max_font_size=300, colormap='Paired').generate_from_frequencies(dict(tags2))

# 사이즈 설정 및 화면에 출력
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
plt.imshow(word_cloud)
plt.axis('off')

plt.show()
